# %% [markdown]
# <a href="https://colab.research.google.com/github/duchaba/Data-Augmentation-with-Python/blob/main/data_augmentation_with_python_chapter_5_with_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌻 Welcome to Chapter 5, Text Augmentation
#
#
# ---
#
# I am glad to see you using this Python Notebook. 🐶
#
# The Python Notebook is an integral part of the book. You can add new “code cells” to extend the functions, add your data, and explore new possibilities, such as downloading additional real-world datasets from the Kaggle website and coding the **Fun challenges**. Furthermore, the book has **Fun facts**, in-depth discussion about augmentation techniques, and Pluto, an imaginary Siberian Huskey coding companion. Together they will guide you every steps of the way.
#
# Pluto encourages you to copy or save a copy of this Python Notebook to your local space and add the “text cells” to keep your notes. In other words, read the book and copy the relevant concept to this Python Notebook’s text-cells. Thus, you can have the explanation, note, original code, your code, and any crazy future ideas in one place.
#
#
# 💗 I hope you enjoy reading the book and hacking code as much as I enjoy writing it.
#
#
# ## 🌟 Amazon Book
#
# ---
#
# - The book is available on the Amazon Book website:
#   - https://www.amazon.com/dp/1803246456
#
#   - Author: Duc Haba
#   - Published: 2023
#   - Page count: 390+
#
#
# - The original Python Notebook is on:
#   - https://github.com/PacktPublishing/Data-Augmentation-with-Python/blob/main/Chapter_5/data_augmentation_with_python_chapter_5.ipynb
#
# - 🚀 Click on the blue "Open in Colab" button at the top of this page to begin hacking.

# %% [markdown]
# # 😀 Excerpt from Chapter 5, Text Augmentation
#
# ---
#
# > In case you haven’t bought the book. Here is an teaser from the first page of Chapter 5.
#
# ---
#
# Text augmentation is a technique that is used in Natural Language Processing (NLP) to generate additional data by modifying or creating new text from existing text data. Text augmentation involves techniques such as character swapping, noise injection, synonym replacement, word deletion, word insertion, and word swapping. Image and text augmentation have the same goal. They strive to increase the size of the training dataset and improve AI prediction accuracy.
#
# Text augmentation is relatively more challenging to evaluate because it is not as intuitive as image augmentation. The intent of an image augmentation technique is clear, such as flipping a photo, but a character-swapping technique will be disorienting to the reader. Therefore, readers might perceive the benefits as subjective.
#
# The effectiveness of text augmentation depends on the quality of the generated data and the specific NLP task being performed. It can be challenging to determine the appropriate safe level of text augmentation that is required for a given dataset, and it often requires experimentation and testing to achieve the desired results.
#
# Customer feedback or social media chatter is fair game for text augmentation because the writing is messy and, predominantly, contains grammatical errors. Conversely, legal documents or written medical communications, such as doctor’s prescriptions or reports, are off-limits because the message is precise. In other words, error injections, synonyms, or even AI-generated text might change the legal or medical meaning beyond the safe level.
#
# The biases in text augmentation are equally difficult to discern. For example, adding noise by purposing misspell words using the Keyboard augmentation method might introduce bias against real-world tweets, which typically contain misspelled words. There are no generalized rules to follow, and the answer only becomes evident after thoroughly studying the data and reviewing the AI forecasting objective.
#
# ---
#
# Fun fact
#
# ---
#
# As generative AI becomes more widely available, you can use OpenAI’s GPT-3, Google Bard or Facebook’s Roberta system to generate original articles for text augmentation. For example, you can ask generative AI to create positive or negative reviews about a company product, then use the AI-written articles to train predictive AI on sentiment analysis.
#
# ---
#
# In Chapter 5, you will learn about text augmentation and how to code the methods in Python notebooks. In particular, we will cover the following topics:
#
# - Character augmenting
#
# - Word augmenting
#
# - Sentence and flow augmenting
#
# - Text augmentation libraries
#
# - Real-world text datasets
#
# - Reinforce learning through Python Notebook
#
# Let’s get started with the simplest topic, character augmentation.
#
# ---
#
# 🌴 *end of excerpt from the book*

# %% [markdown]
# # GitHub Clone

# %%
# git version should be 2.17.1 or higher
# !git --version
# Out:
# git version 2.25.1

# %%
url = 'https://github.com/PacktPublishing/Data-Augmentation-with-Python'
# !git clone {url}
# Out:
# Cloning into 'Data-Augmentation-with-Python'...
# remote: Enumerating objects: 162, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (91/91), done.
# remote: Total 162 (delta 73), reused 108 (delta 48), pack-reused 22
# Receiving objects: 100% (162/162), 13.24 MiB | 13.78 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %% [markdown]
# ## Fetch file from URL (Optional)
#
# - Uncommend the below 2 code cells if you want to use URL and not Git Clone

# %%
# import requests
# #
# def fetch_file(url, dst):
#   downloaded_obj = requests.get(url)
#   with open(dst, "wb") as file:
#     file.write(downloaded_obj.content)
#   return

# %%
# url = ''
# dst = 'pluto_chapter_1.py'
# fetch_file(url,dst)

# %% [markdown]
# # Run Pluto
#
# - Instantiate up Pluto, aka. "Pluto, wake up!"

# %%
# %% CARRY-OVER code install

# !pip install opendatasets --upgrade
# !pip install pyspellchecker
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.2-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 11.6 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2

# %%
#load and run the pluto chapter 1 Python code.
pluto_file = 'Data-Augmentation-with-Python/pluto/pluto_chapter_2.py'
# %run {pluto_file}
# Out:
# ---------------------------- : ----------------------------
#             Hello from class : <class '__main__.PacktDataAug'> Class: PacktDataAug
#                    Code name : Pluto
#                    Author is : Duc Haba
# ---------------------------- : ----------------------------

# %% [markdown]
# # Verify Pluto

# %%
pluto.say_sys_info()
# Out:
# ---------------------------- : ----------------------------
#                  System time : 2023/04/26 21:25
#                     Platform : linux
#      Pluto Version (Chapter) : 2.0
#              Python (3.7.10) : actual: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#             PyTorch (1.11.0) : actual: 2.0.0+cu118
#               Pandas (1.3.5) : actual: 1.5.3
#                  PIL (9.0.0) : actual: 8.4.0
#           Matplotlib (3.2.2) : actual: 3.7.1
#                    CPU count : 2
#                    CPU speed : 2.20 GHz
#                CPU max speed : 0.00 GHz
# ---------------------------- : ----------------------------

# %% [markdown]
# ## (Optional) Export to .py

# %%
pluto_chapter_5 = 'Data-Augmentation-with-Python/pluto/pluto_chapter_5.py'
# !cp {pluto_file} {pluto_chapter_5}

# %% [markdown]
# # ✋ Set up Kaggle username and app Key
#
# - Install the following libraries, and import it on the Notebook.
# - Follow by initialize Kaggle username, key and fetch methods.
# - STOP: Update your Kaggle access username or key first.

# %%
# %%CARRY-OVER code 

# -------------------- : --------------------
# READ ME
# Chapter 2 begin:
# Install the following libraries, and import it on the Notebook.
# Follow by initialize Kaggle username, key and fetch methods.
# STOP: Update your Kaggle access username or key first.
# -------------------- : --------------------

# !pip install opendatasets --upgrade
import opendatasets
print("\nrequired version 0.1.22 or higher: ", opendatasets.__version__)

# !pip install pyspellchecker 
import spellchecker
print("\nRequired version 0.7+", spellchecker.__version__)

# STOP: Update your Kaggle access username or key first.
pluto.remember_kaggle_access_keys("YOUR_KAGGLE_USERNAME", "YOUR_KAGGLE_API_KEY")
pluto._write_kaggle_credit()
import kaggle

@add_method(PacktDataAug)
def fetch_kaggle_comp_data(self,cname):
  #self._write_kaggle_credit()  # need to run only once.
  path = pathlib.Path(cname)
  kaggle.api.competition_download_cli(str(path))
  zipfile.ZipFile(f'{path}.zip').extractall(path)
  return

@add_method(PacktDataAug)
def fetch_kaggle_dataset(self,url,dest="kaggle"):
  #self._write_kaggle_credit()    # need to run only once.
  opendatasets.download(url,data_dir=dest)
  return
# -------------------- : --------------------
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.9/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
#
# required version 0.1.22 or higher:  0.1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.9/dist-packages (0.7.2)
#
# Required version 0.7+ 0.7.2

# %% [markdown]
# # Fetch Kaggle Data

# %% [markdown]
# ## NetFlix

# %%
# %%time
url = 'https://www.kaggle.com/datasets/infamouscoder/dataset-netflix-shows'
pluto.fetch_kaggle_dataset(url)
# Out:
# Downloading dataset-netflix-shows.zip to kaggle/dataset-netflix-shows
# 100%|██████████| 1.34M/1.34M [00:00<00:00, 67.1MB/s]
# CPU times: user 90.3 ms, sys: 26.5 ms, total: 117 ms
# Wall time: 526 ms

# %%
f = 'kaggle/dataset-netflix-shows/netflix_titles.csv'
pluto.df_netflix_data = pluto.fetch_df(f)
pluto.df_netflix_data.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...

# %%
pluto.print_batch_text(pluto.df_netflix_data)
# Out:
# <style type="text/css">
# #T_b91ab th {
#   font-size: 20px;
# }
# #T_b91ab td {
#   font-size: 18px;
# }
# </style>
# <table id="T_b91ab" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b91ab_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_b91ab_level0_col1" class="col_heading level0 col1" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b91ab_level0_row0" class="row_heading level0 row0" >8751</th>
#       <td id="T_b91ab_row0_col0" class="data row0 col0" >Wish I Was Here</td>
#       <td id="T_b91ab_row0_col1" class="data row0 col1" >With his acting career moribund, Aidan Bloom steers a new tack in life, taking over his children's education when private school becomes too costly.</td>
#     </tr>
#     <tr>
#       <th id="T_b91ab_level0_row1" class="row_heading level0 row1" >3440</th>
#       <td id="T_b91ab_row1_col0" class="data row1 col0" >Rhythm + Flow</td>
#       <td id="T_b91ab_row1_col1" class="data row1 col1" >In this music competition show, judges Tip âT.I.â Harris, Cardi B and Chance the Rapper hit the streets to find the next rap superstar.</td>
#     </tr>
#     <tr>
#       <th id="T_b91ab_level0_row2" class="row_heading level0 row2" >8594</th>
#       <td id="T_b91ab_row2_col0" class="data row2 col0" >Tinker Bell and the Legend of the NeverBeast</td>
#       <td id="T_b91ab_row2_col1" class="data row2 col1" >When suspicious scout fairies scheme to capture the fearsome-looking NeverBeast, Tinker Bell and Fawn set out to save the wondrous creature.</td>
#     </tr>
#     <tr>
#       <th id="T_b91ab_level0_row3" class="row_heading level0 row3" >5778</th>
#       <td id="T_b91ab_row3_col0" class="data row3 col0" >Umrika</td>
#       <td id="T_b91ab_row3_col1" class="data row3 col1" >An ambitious man leaves his small Indian village for America. But when his letters to home stop coming, his brother sets out on his own adventure.</td>
#     </tr>
#     <tr>
#       <th id="T_b91ab_level0_row4" class="row_heading level0 row4" >2603</th>
#       <td id="T_b91ab_row4_col0" class="data row4 col0" >The Victims' Game</td>
#       <td id="T_b91ab_row4_col1" class="data row4 col1" >After discovering his estranged daughter's link to mysterious murders, a forensic detective with Asperger's syndrome risks everything to solve the case.</td>
#     </tr>
#     <tr>
#       <th id="T_b91ab_level0_row5" class="row_heading level0 row5" >4627</th>
#       <td id="T_b91ab_row5_col0" class="data row5 col0" >Battlefish</td>
#       <td id="T_b91ab_row5_col1" class="data row5 col1" >Over the course of a fishing season, tough men and women pursue lucrative albacore tuna in the competitive waters off the Oregon coast.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.count_word(pluto.df_netflix_data)
pluto.df_netflix_data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  wordc
# 0  As her father nears the end of his life, filmm...     27
# 1  After crossing paths at a party, a Cape Town t...     27
# 2  To protect his family from a powerful drug lor...     27
# 3  Feuds, flirtations and toilet talk go down amo...     24
# 4  In a city of coaching centers known to train I...     24

# %%
pluto.draw_word_count(pluto.df_netflix_data)

# %%
# %%CARRY-OVER code install

# !pip install missingno
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingno in /usr/local/lib/python3.9/dist-packages (0.5.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from missingno) (0.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from missingno) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from missingno) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from missingno) (1.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.9/dist-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->missingno) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->seaborn->missingno) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
# %%writefile -a {pluto_chapter_5}

pluto.version = 5.0
import missingno
@add_method(PacktDataAug)
def draw_text_null_data(self, df, color=(0.3,0.36,0.44)):
  canvas, pic = matplotlib.pyplot.subplots(1, 1, figsize=(10, 6))
  missingno.matrix(df,color=color,ax=pic)
  pic.set_title('Missing Data (Null Value)')
  pic.set_xlabel('Solid is has data. White line is missing/null data.')
  canvas.tight_layout()
  self._drop_image(canvas)
  canvas.show()
  return

# %%
pluto.draw_text_null_data(pluto.df_netflix_data)
# Out:
# /usr/local/lib/python3.9/dist-packages/missingno/missingno.py:61: UserWarning: Plotting a sparkline on an existing axis is not currently supported. To remove this warning, set sparkline=False.
#   warnings.warn(

# %%
# %%CARRY-OVER code install

# !pip install nltk
# !pip install wordcloud
#
# tested with the following version
# !pip install nltk==3.8.1
# !pip install wordcloud==1.8.2.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (1.8.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# %%writefile -a {pluto_chapter_5}

import nltk
import wordcloud
import re
@add_method(PacktDataAug)
def _draw_image_wordcloud(self, words_str, xignore_words='cat', title='Word Cloud:'):
  canvas, pic = matplotlib.pyplot.subplots(1, 1, figsize=(16, 8))
  img = wordcloud.WordCloud(width = 1400, 
    height = 800, 
    background_color ='white',
    stopwords = xignore_words, 
    min_font_size = 10).generate(words_str) 
  pic.imshow(img)
  pic.set_title(title)
  pic.set_xlabel(f'Approximate Words: {int(len(words_str) / 5)}')
  pic.tick_params(left = False, right = False, labelleft = False,
    labelbottom = False, bottom = False)
  canvas.tight_layout()
  self._drop_image(canvas)
  canvas.show()
  return
  #
@add_method(PacktDataAug)
def draw_text_wordcloud(self, df_1column, xignore_words='cat', title='Word Cloud:'):
  orig = df_1column.str.cat()
  clean = re.sub('[^A-Za-z0-9 ]+', '', orig)
  self._draw_image_wordcloud(clean, xignore_words=xignore_words,title=title)
  return

# %%
print('Nltk version 3.7: actual: ', nltk.__version__)
print('WordCloud version 1.8.2.2: actual: ', wordcloud.__version__)
# Out:
# Nltk version 3.7: actual:  3.8.1
# WordCloud version 1.8.2.2: actual:  1.8.2.2

# %%
pluto.draw_text_wordcloud(pluto.df_netflix_data.description, 
  xignore_words=wordcloud.STOPWORDS, 
  title='Word Cloud: Netflix Movie Review')

# %% [markdown]
# ## Twitter

# %%
# @add_method(PacktDataAug)
# def fetch_df(self, csv):
#   df = pandas.read_csv(csv, encoding='latin-1')
#   return df

# %%
# 
# %%time
url = 'https://www.kaggle.com/datasets/mayurdalvi/twitter-sentiments-analysis-nlp'
pluto.fetch_kaggle_dataset(url)
# Out:
# Downloading twitter-sentiments-analysis-nlp.zip to kaggle/twitter-sentiments-analysis-nlp
# 100%|██████████| 1.23M/1.23M [00:00<00:00, 40.1MB/s]
# CPU times: user 94.2 ms, sys: 19.8 ms, total: 114 ms
# Wall time: 586 ms

# %%
# remove white space in directory and filename
# run this until no error/output
f = 'kaggle/twitter-sentiments-analysis-nlp'
#!find {f} -name "* *" -type d | rename 's/ /_/g'
# !find {f} -name "* *" -type f | rename 's/ /_/g'

# %%
f = 'kaggle/twitter-sentiments-analysis-nlp/Twitter_Sentiments.csv'
pluto.df_twitter_data = pluto.fetch_df(f)
pluto.df_twitter_data.head(3)
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty

# %%
pluto.print_batch_text(pluto.df_twitter_data,cols=['label', 'tweet'])
# Out:
# <style type="text/css">
# #T_26b88 th {
#   font-size: 20px;
# }
# #T_26b88 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_26b88" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26b88_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_26b88_level0_col1" class="col_heading level0 col1" >tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26b88_level0_row0" class="row_heading level0 row0" >13283</th>
#       <td id="T_26b88_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_26b88_row0_col1" class="data row0 col1" >foods for #healing your body!!    #altwaystoheal #healthy is  !! </td>
#     </tr>
#     <tr>
#       <th id="T_26b88_level0_row1" class="row_heading level0 row1" >9563</th>
#       <td id="T_26b88_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_26b88_row1_col1" class="data row1 col1" >  couple having sex porntube net  </td>
#     </tr>
#     <tr>
#       <th id="T_26b88_level0_row2" class="row_heading level0 row2" >31736</th>
#       <td id="T_26b88_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_26b88_row2_col1" class="data row2 col1" >yes..mind you not only counting you have to find them... very few hospitals are digitized.. need to improve hmis </td>
#     </tr>
#     <tr>
#       <th id="T_26b88_level0_row3" class="row_heading level0 row3" >27797</th>
#       <td id="T_26b88_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_26b88_row3_col1" class="data row3 col1" >sometimes you just have to look nice. #fashion #lookingsharp #dressedup   #shiandtie #tieÃ¢ÂÂ¦ </td>
#     </tr>
#     <tr>
#       <th id="T_26b88_level0_row4" class="row_heading level0 row4" >23688</th>
#       <td id="T_26b88_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_26b88_row4_col1" class="data row4 col1" >hate still alive and well i see!   #hater #orlandounited  </td>
#     </tr>
#     <tr>
#       <th id="T_26b88_level0_row5" class="row_heading level0 row5" >5763</th>
#       <td id="T_26b88_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_26b88_row5_col1" class="data row5 col1" > @user time of our lives  @user doors opening left right and centre.   Ã¢ÂÂ¤Ã¯Â¸ÂÃ¢ÂÂ¤Ã¯Â¸ÂÃ¢ÂÂ¤Ã¯Â¸Â</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%CARRY-OVER code install

# !pip install filter-profanity
#
# tested on the following on version:
#!pip install filter-profanity==1.0.9
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting filter-profanity
#   Downloading filter-profanity-1.0.9.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: filter-profanity
#   Building wheel for filter-profanity (setup.py) ... done
#   Created wheel for filter-profanity: filename=filter_profanity-1.0.9-py3-none-any.whl size=5219 sha256=3b070538386620cdffa798a41a64febb19ffb44629da0d13470df3462eeefe23
#   Stored in directory: /root/.cache/pip/wheels/48/fc/0d/0d23257e5c9bd082786e83a863e2721072170558686d55eba9
# Successfully built filter-profanity
# Installing collected packages: filter-profanity
# Successfully installed filter-profanity-1.0.9

# %%
# %%writefile -a {pluto_chapter_5}

import profanity
import re
#
@add_method(PacktDataAug)
def _clean_text(self,x):
  return (re.sub('[^A-Za-z0-9 .,!?#@]+', '', str(x)))
#
@add_method(PacktDataAug)
def _clean_bad_word(self,x):
  return (profanity.censor_profanity(x, ''))
#
@add_method(PacktDataAug)
def clean_text(self, df):
  df['clean_tweet'] = df.tweet.apply(self._clean_text)
  df['clean_tweet'] = df['clean_tweet'].apply(self._clean_bad_word)
  return df

# %%
# %%time
pluto.clean_text(pluto.df_twitter_data)
pluto.df_twitter_data.head()
#
pluto.df_netflix_data['description'] = pluto.df_netflix_data['description'].apply(pluto._clean_text)
# Out:
# CPU times: user 2.92 s, sys: 7.81 ms, total: 2.93 s
# Wall time: 3.02 s

# %%
pluto.print_batch_text(pluto.df_twitter_data, cols=['label', 'clean_tweet'])
# Out:
# <style type="text/css">
# #T_5ebc5 th {
#   font-size: 20px;
# }
# #T_5ebc5 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_5ebc5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ebc5_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_5ebc5_level0_col1" class="col_heading level0 col1" >clean_tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ebc5_level0_row0" class="row_heading level0 row0" >9300</th>
#       <td id="T_5ebc5_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5ebc5_row0_col1" class="data row0 col1" >well they kind of work.. snapseed stopped working within the editing.. #somad #headset</td>
#     </tr>
#     <tr>
#       <th id="T_5ebc5_level0_row1" class="row_heading level0 row1" >15716</th>
#       <td id="T_5ebc5_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_5ebc5_row1_col1" class="data row1 col1" >@user my #chopperlove, thoughts amp prayers go out 2 all victims amp their families in this horrific tragedy, mass shooting in o</td>
#     </tr>
#     <tr>
#       <th id="T_5ebc5_level0_row2" class="row_heading level0 row2" >25827</th>
#       <td id="T_5ebc5_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_5ebc5_row2_col1" class="data row2 col1" >the cake was good but undercooked #bad #cook</td>
#     </tr>
#     <tr>
#       <th id="T_5ebc5_level0_row3" class="row_heading level0 row3" >11768</th>
#       <td id="T_5ebc5_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_5ebc5_row3_col1" class="data row3 col1" >@user i know times</td>
#     </tr>
#     <tr>
#       <th id="T_5ebc5_level0_row4" class="row_heading level0 row4" >5907</th>
#       <td id="T_5ebc5_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_5ebc5_row4_col1" class="data row4 col1" >@user @user @user it was just an #aftehought after all!</td>
#     </tr>
#     <tr>
#       <th id="T_5ebc5_level0_row5" class="row_heading level0 row5" >22003</th>
#       <td id="T_5ebc5_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_5ebc5_row5_col1" class="data row5 col1" >people watching is on fleek #vegas #whatpeoplewear #tattooofwhat</td>
#     </tr>
#   </tbody>
# </table>

# %%
# double check on clean tweets
print('clean: ', pluto.df_twitter_data.clean_tweet[13538], ' : original: ', 
  pluto.df_twitter_data.tweet[13538], ': label: ', pluto.df_twitter_data.label[13538])
# Out:
# clean:  black girl  teen virgin  pictures  : original:   black girl porn teen virgin sex pictures  : label:  1

# %%
# double check on clean tweets
with pandas.option_context("display.max_colwidth", None):
  display(pluto.df_twitter_data[pluto.df_twitter_data.label == 1].sample(10))
# Out:
#           id  label  \
# 17857  17858      1
# 151      152      1
# 22420  22421      1
# 18156  18157      1
# 29080  29081      1
# 30659  30660      1
# 7325    7326      1
# 11443  11444      1
# 3806    3807      1
# 7846    7847      1
#
#                                                                                                                      tweet  \
# 17857           thought factory: left-right polarisation! #trump #uselections2016 #leadership #politics  #brexit #blm +12
# 151    yes it's  when you call #michelleobama a gorilla because racists have long thought of black people as no betÃ¢ÂÂ¦
# 22420                         no comment!  in #australia   #opkillingbay #seashepherd #helpcovedolphins #thecove  #redcove
# 18156  #carlpaladino, a**hole extraordinaire.  this guy is a #trump hero of course #gop  #fascismo, wishes obama deÃ¢ÂÂ¦
# 29080                                               fo woh pastors say officer's acts in viral video arrests were racist
# 30659                                                           @user the real jeff sessions.   #neverump #swampmonster  #
# 7325                     @user #allahsoil vps got multi-million dollar bonuses while average americans lost their homes.
# 11443                                   @user #netanyahuspeech stirs anti-jewish hate &amp;  on twitter from progressives
# 3806        wants obama to catch mad cow disease after being caught w/herford. dies before trial. buried in cow pasture.
# 7846                aptly named... we have whitesboro in ny with its ndn killing town seal, and whiteland with its mascot
#
#                                                                                                        clean_tweet
# 17857        thought factory leftright polarisation! #trump #uselections2016 #leadership #politics #brexit #blm 12
# 151     yes its when you call #michelleobama a gorilla because racists have long thought of black people as no bet
# 22420                     no comment! in #australia #opkillingbay #seashepherd #helpcovedolphins #thecove #redcove
# 18156     #carlpaladino, ahole extraordinaire. this guy is a #trump hero of course #gop #fascismo, wishes obama de
# 29080                                          fo woh pastors say officers acts in viral video arrests were racist
# 30659                                                      @user the real jeff sessions. #neverump #swampmonster #
# 7325                @user #allahsoil vps got multimillion dollar bonuses while average americans lost their homes.
# 11443                                @user #netanyahuspeech stirs antijewish hate amp on twitter from progressives
# 3806   wants obama to catch mad cow disease after being caught wherford. dies before trial. buried in cow pasture.
# 7846         aptly named... we have whitesboro in ny with its ndn killing town seal, and whiteland with its mascot

# %%
pluto.count_word(pluto.df_twitter_data,col_dest='clean_tweet')
pluto.draw_word_count(pluto.df_twitter_data)

# %%
pluto.draw_text_null_data(pluto.df_twitter_data)
# Out:
# /usr/local/lib/python3.9/dist-packages/missingno/missingno.py:61: UserWarning: Plotting a sparkline on an existing axis is not currently supported. To remove this warning, set sparkline=False.
#   warnings.warn(

# %%
pluto.draw_text_wordcloud(pluto.df_twitter_data.clean_tweet,
  xignore_words=wordcloud.STOPWORDS,
  title='Clean Tweets Word Cloud')

# %% [markdown]
# # Export (aka drop or save) data file

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def _drop_df_file(self, df,fname,type='csv',sep='~'):
  df.to_csv(fname,sep=sep)
  return

# %%
f = 'Data-Augmentation-with-Python/pluto_data/netflix_data.csv'
pluto._drop_df_file(pluto.df_netflix_data, f)

# %%
f = 'Data-Augmentation-with-Python/pluto_data/twitter_data.csv'
pluto._drop_df_file(pluto.df_twitter_data, f)

# %% [markdown]
# # Character Augmenter<a class="anchor" id="chara_aug">
#
# Augmenting data in character level. Possible scenarios include image to text and chatbot. During recognizing text from image, we need to optical character recognition (OCR) model to achieve it but OCR introduces some errors such as recognizing "o" and "0". `OCRAug` simulate these errors to perform the data augmentation. For chatbot, we still have typo even though most of application comes with word correction. Therefore, `KeyboardAug` is introduced to simulate this kind of errors.

# %%
# %%CARRY-OVER code install

# !pip install nlpaug
#
# tested on the following version:
#!pip install nlpaug==1.1.11
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nlpaug
#   Downloading nlpaug-1.1.11-py3-none-any.whl (410 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (1.22.4)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (4.6.6)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (2.27.1)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (1.5.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (4.11.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (3.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->nlpaug) (2022.7.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (1.7.1)
# Installing collected packages: nlpaug
# Successfully installed nlpaug-1.1.11

# %%
# %%writefile -a {pluto_chapter_5}

import nlpaug
import nlpaug.augmenter
import nlpaug.augmenter.char
import nlpaug.augmenter.word

# %%
print('version 1.1.11, actual: ',nlpaug.__version__)
# Out:
# version 1.1.11, actual:  1.1.11

# %%
# %%writefile -a {pluto_chapter_5}

pluto.orig_text = 'It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.'

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def _print_aug_batch(self, df, aug_func, col_dest="description",
  bsize=3, aug_name='Augmented',is_larger_font=True):
  col_name = [aug_name, 'Original']
  aug = aug_func.augment(self.orig_text, n=1)
  data = [[aug[0], self.orig_text]]
  df_aug = pandas.DataFrame(data, columns=col_name)
  orig = df[col_dest].sample(bsize)
  for tx in orig:
    aug = aug_func.augment(tx, n=1)
    data = [[aug[0], tx]]
    t = pandas.DataFrame(data, columns=col_name)
    df_aug = df_aug.append(t, ignore_index=True)
  #
  with pandas.option_context("display.max_colwidth", None):
    if (is_larger_font):
      display(df_aug.head(bsize+1).style.set_table_styles(self._fetch_larger_font()))
    else:
      display(df_aug.head(bsize+1))
  return

# %% [markdown]
# ## OCR augmenting

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_ocr(self, df, col_dest="description",bsize=3, aug_name='Augmented'):
  aug_func = nlpaug.augmenter.char.OcrAug()
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_ocr(pluto.df_netflix_data, col_dest='description',aug_name='OCR Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_69b18 th {
#   font-size: 20px;
# }
# #T_69b18 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_69b18" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69b18_level0_col0" class="col_heading level0 col0" >OCR Augment</th>
#       <th id="T_69b18_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69b18_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69b18_row0_col0" class="data row0 col0" >1t was the 6e8t of times. It was the worst of times. It wa8 the age 0f wi8d0m. It wa8 the age uf foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_69b18_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_69b18_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69b18_row1_col0" class="data row1 col0" >When they lose their passports, a bickering kadiu team invent8 phony reports from a combat zone in a ruse that becomes inckea8in91y c0mp1icated.</td>
#       <td id="T_69b18_row1_col1" class="data row1 col1" >When they lose their passports, a bickering radio team invents phony reports from a combat zone in a ruse that becomes increasingly complicated.</td>
#     </tr>
#     <tr>
#       <th id="T_69b18_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69b18_row2_col0" class="data row2 col0" >While investigating a ridnappin9, an excop 8ent to infiltrate a prison finds himself surrounded 6y dangerous felons wh0 cant know hi8 real identity.</td>
#       <td id="T_69b18_row2_col1" class="data row2 col1" >While investigating a kidnapping, an excop sent to infiltrate a prison finds himself surrounded by dangerous felons who cant know his real identity.</td>
#     </tr>
#     <tr>
#       <th id="T_69b18_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69b18_row3_col0" class="data row3 col0" >This ducoserie8 follows the highprofile case of Ee19ian p01itician Bernard Wesphael, whu wa8 acco8ed of murdering his wife in 2013.</td>
#       <td id="T_69b18_row3_col1" class="data row3 col1" >This docuseries follows the highprofile case of Belgian politician Bernard Wesphael, who was accused of murdering his wife in 2013.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ocr(pluto.df_twitter_data, col_dest='clean_tweet',aug_name='OCR Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_cd07d th {
#   font-size: 20px;
# }
# #T_cd07d td {
#   font-size: 18px;
# }
# </style>
# <table id="T_cd07d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd07d_level0_col0" class="col_heading level0 col0" >OCR Augment</th>
#       <th id="T_cd07d_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd07d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd07d_row0_col0" class="data row0 col0" >It was the best of times. It was the worst of time8. It was the age of wisdom. It was the a9e of foolishness. It was the epoch of belief. It wa8 the epoch of incredulity.</td>
#       <td id="T_cd07d_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_cd07d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd07d_row1_col0" class="data row1 col0" ># quoteoftheday bull up yuo will dominate your 6u1l and yuo will direct it whatevek you want it to do. whe</td>
#       <td id="T_cd07d_row1_col1" class="data row1 col1" >#quoteoftheday bull up you will dominate your bull and you will direct it whatever you want it to do. whe</td>
#     </tr>
#     <tr>
#       <th id="T_cd07d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd07d_row2_col0" class="data row2 col0" >videos uf chinese a9ain8t women in the workplace</td>
#       <td id="T_cd07d_row2_col1" class="data row2 col1" > videos of chinese against women in the workplace</td>
#     </tr>
#     <tr>
#       <th id="T_cd07d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd07d_row3_col0" class="data row3 col0" >this i8 co01 hea1thy # heatherfitzpatrick # smile # lifeisgood # interesting 8 i95</td>
#       <td id="T_cd07d_row3_col1" class="data row3 col1" >this is cool healthy #heatherfitzpatrick #smile #lifeisgood #interesting @ i95</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Keyboard Augmenter<a class="anchor" id="keyboard_aug"></a>

# %% [markdown]
# - Substitute character by keyboard distance

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_keyboard(self, df, col_dest="description",bsize=3, aug_name='Keyboard Augment'):
  aug_func = nlpaug.augmenter.char.KeyboardAug()
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_keyboard(pluto.df_netflix_data, col_dest='description',
  aug_name='Keyboard Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_e8fd9 th {
#   font-size: 20px;
# }
# #T_e8fd9 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_e8fd9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8fd9_level0_col0" class="col_heading level0 col0" >Keyboard Augment</th>
#       <th id="T_e8fd9_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8fd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8fd9_row0_col0" class="data row0 col0" >It was the bFEt of timDx. It was the w)rs% of t*m$s. It was the age of wisfoJ. It was the age of fool7sTndcs. It was the 4Loch of b@,ief. It was the epkxh of incred*loF6.</td>
#       <td id="T_e8fd9_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_e8fd9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8fd9_row1_col0" class="data row1 col0" >When dayxrDame3 Iajaan is sent to biard(nb sfhKol, an unconventional art teacher tries to help the imQginAFiv2 WtudeJ5 disf)vwr his rrhe identity.</td>
#       <td id="T_e8fd9_row1_col1" class="data row1 col1" >When daydreamer Ishaan is sent to boarding school, an unconventional art teacher tries to help the imaginative student discover his true identity.</td>
#     </tr>
#     <tr>
#       <th id="T_e8fd9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8fd9_row2_col0" class="data row2 col0" >Wh@G his future siCtd%Onlaw is kidnapped by timan 5raDfickeDz, a m9ljtart Detfrzn joins ford$s wkHh his brothers and a worldweary cop to rescue her.</td>
#       <td id="T_e8fd9_row2_col1" class="data row2 col1" >When his future sisterinlaw is kidnapped by human traffickers, a military veteran joins forces with his brothers and a worldweary cop to rescue her.</td>
#     </tr>
#     <tr>
#       <th id="T_e8fd9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8fd9_row3_col0" class="data row3 col0" >A modern l0Ge s6*ry is cLnn$Vted to an aBci4nh fkpk tale as starcrossed lov4es from v8ffsrent social c>WZses are kept apart by their families.</td>
#       <td id="T_e8fd9_row3_col1" class="data row3 col1" >A modern love story is connected to an ancient folk tale as starcrossed lovers from different social classes are kept apart by their families.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_keyboard(pluto.df_twitter_data, col_dest='clean_tweet',
  aug_name='Keyboard Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_43d9a th {
#   font-size: 20px;
# }
# #T_43d9a td {
#   font-size: 18px;
# }
# </style>
# <table id="T_43d9a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43d9a_level0_col0" class="col_heading level0 col0" >Keyboard Augment</th>
#       <th id="T_43d9a_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43d9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43d9a_row0_col0" class="data row0 col0" >It was the bwZt of h7mes. It was the Qorsr of tUmez. It was the age of wLsWom. It was the age of floljshgeXs. It was the eLlch of fePief. It was the epKcN of inFfedulory.</td>
#       <td id="T_43d9a_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_43d9a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43d9a_row1_col0" class="data row1 col0" ># mIdeo i /oGe u RaJe wohh u all the t(<e in ur! !!</td>
#       <td id="T_43d9a_row1_col1" class="data row1 col1" >#model i love u take with u all the time in ur!!!</td>
#     </tr>
#     <tr>
#       <th id="T_43d9a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43d9a_row2_col0" class="data row2 col0" >@ user fwthe%D day # daddygeHl KaTi y nats so Fu%ies and pdW4ties @ 7sdr @ user</td>
#       <td id="T_43d9a_row2_col1" class="data row2 col1" >@user fathers day #daddybeto mari y nats so cuties and pretties @user @user</td>
#     </tr>
#     <tr>
#       <th id="T_43d9a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43d9a_row3_col0" class="data row3 col0" >i Danf beljeff that 3 w@els vacsFoon is )vdr # sesameplacepa # uBvorgetyablr # theresalwaysakidinus # back2work</td>
#       <td id="T_43d9a_row3_col1" class="data row3 col1" >i cant believe that 3 weeks vacation is over #sesameplacepa #unforgettable #theresalwaysakidinus #back2work</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Random Augmenter<a class="anchor" id="random_aug"></a>

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_char_random(self, df, action='insert', col_dest="description",bsize=3, aug_name='Augment'):
  aug_func = nlpaug.augmenter.char.RandomCharAug(action=action)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_char_random(pluto.df_netflix_data, action='insert', 
  col_dest='description', aug_name='Random Insert Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_85478 th {
#   font-size: 20px;
# }
# #T_85478 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_85478" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85478_level0_col0" class="col_heading level0 col0" >Random Insert Augment</th>
#       <th id="T_85478_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85478_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85478_row0_col0" class="data row0 col0" >It was the Cbe*st of timVeRs. It was the BworsFt of 4tiKmes. It was the age of 6wisdqom. It was the age of fo*ozlisYhnpess. It was the eZpoIch of mbMelief. It was the emporch of Nienzc@redulity.</td>
#       <td id="T_85478_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_85478_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85478_row1_col0" class="data row1 col0" >Hdakil3ing fr4oYm different cklsasseas, a young man and his wife try to &fiSnd their ve(rcs)ion of hkappiYlhy married when both yeNaErn to gl)eave their old lHivges behind.</td>
#       <td id="T_85478_row1_col1" class="data row1 col1" >Hailing from different classes, a young man and his wife try to find their version of happily married when both yearn to leave their old lives behind.</td>
#     </tr>
#     <tr>
#       <th id="T_85478_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85478_row2_col0" class="data row2 col0" >Two fru!stra3te)d sex lwork2er1s cut out the nmiddlGeYmen from their business aHfNfaivrs and start a cooperative thvatds run eKnt0icrely by w@om%en.</td>
#       <td id="T_85478_row2_col1" class="data row2 col1" >Two frustrated sex workers cut out the middlemen from their business affairs and start a cooperative thats run entirely by women.</td>
#     </tr>
#     <tr>
#       <th id="T_85478_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85478_row3_col0" class="data row3 col0" >)Tvhis rzea3li*ty TV sseriges fo6llNowns the men and women of New Zealands border patrol in their quest to keYemp tnhveir cojuentIry safe and se(cu*re.</td>
#       <td id="T_85478_row3_col1" class="data row3 col1" >This reality TV series follows the men and women of New Zealands border patrol in their quest to keep their country safe and secure.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_char_random(pluto.df_netflix_data, action='delete', 
  col_dest='description', aug_name='Random Delete Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_38ab5 th {
#   font-size: 20px;
# }
# #T_38ab5 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_38ab5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38ab5_level0_col0" class="col_heading level0 col0" >Random Delete Augment</th>
#       <th id="T_38ab5_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38ab5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38ab5_row0_col0" class="data row0 col0" >It was the es of ies. It was the wst of mes. It was the age of wdom. It was the age of folishe. It was the eph of beef. It was the eoc of ncreuly.</td>
#       <td id="T_38ab5_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_38ab5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_38ab5_row1_col0" class="data row1 col0" >Time passes and tsin muts in a Florida police station as an estranged ntercil cope awaits nw of their sing tena son.</td>
#       <td id="T_38ab5_row1_col1" class="data row1 col1" >Time passes and tension mounts in a Florida police station as an estranged interracial couple awaits news of their missing teenage son.</td>
#     </tr>
#     <tr>
#       <th id="T_38ab5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_38ab5_row2_col0" class="data row2 col0" >In a film aed on true eens, an wkar but amious TV porer srgles to adapt when hs rdee to focus on vlet and salacious stories.</td>
#       <td id="T_38ab5_row2_col1" class="data row2 col1" >In a film based on true events, an awkward but ambitious TV reporter struggles to adapt when shes ordered to focus on violent and salacious stories.</td>
#     </tr>
#     <tr>
#       <th id="T_38ab5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_38ab5_row3_col0" class="data row3 col0" >A 15yearold from LA seds the sumr at her om cildho hm on an island off the coast of England, where she bon wt a mysteos rse.</td>
#       <td id="T_38ab5_row3_col1" class="data row3 col1" >A 15yearold from LA spends the summer at her moms childhood home on an island off the coast of England, where she bonds with a mysterious horse.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_char_random(pluto.df_netflix_data, action='substitute', 
  col_dest='description', aug_name='Random Substitute Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_99341 th {
#   font-size: 20px;
# }
# #T_99341 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_99341" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_99341_level0_col0" class="col_heading level0 col0" >Random Substitute Augment</th>
#       <th id="T_99341_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99341_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99341_row0_col0" class="data row0 col0" >It was the b$st of $i*es. It was the wmrs! of timID. It was the age of wLsd)m. It was the age of fkClisDness. It was the etoc# of beDied. It was the ppo!h of inaNed8Kity.</td>
#       <td id="T_99341_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_99341_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99341_row1_col0" class="data row1 col0" >A topranked college m*rchank bands meHVerD f#Nht to kgQp their spjNs, memorize routines, tVnT to their 8o*ial lives and slay the cvmp9tItqon.</td>
#       <td id="T_99341_row1_col1" class="data row1 col1" >A topranked college marching bands members fight to keep their spots, memorize routines, tend to their social lives  and slay the competition.</td>
#     </tr>
#     <tr>
#       <th id="T_99341_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99341_row2_col0" class="data row2 col0" >Despite public huoiBioAion and resistance, an entrepreneur markets a hygienic, lowcost scnEtari pad t9Gt even IndizW 7sorVst wo4Nn can pVford.</td>
#       <td id="T_99341_row2_col1" class="data row2 col1" >Despite public humiliation and resistance, an entrepreneur markets a hygienic, lowcost sanitary pad that even Indias poorest women can afford.</td>
#     </tr>
#     <tr>
#       <th id="T_99341_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99341_row3_col0" class="data row3 col0" >At an Afghanistan rgfVget c&gp, an exaumw doctor seeks to vriTg children joy KhrouLy Ziiceet and soon realizes that the sda*es go beylnG the spbWt.</td>
#       <td id="T_99341_row3_col1" class="data row3 col1" >At an Afghanistan refugee camp, an exarmy doctor seeks to bring children joy through cricket  and soon realizes that the stakes go beyond the sport.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_char_random(pluto.df_netflix_data, action='swap', 
  col_dest='description', aug_name='Random Swap Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_c0c26 th {
#   font-size: 20px;
# }
# #T_c0c26 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_c0c26" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0c26_level0_col0" class="col_heading level0 col0" >Random Swap Augment</th>
#       <th id="T_c0c26_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0c26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0c26_row0_col0" class="data row0 col0" >It was the bste of times. It was the orwst of tmise. It was the age of iswdom. It was the age of foolishnses. It was the peohc of belief. It was the oepch of incredulity.</td>
#       <td id="T_c0c26_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_c0c26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0c26_row1_col0" class="data row1 col0" >After a zombie outbreak in Las Evgsa, a group of mercenaries atkse the ultimate gabmel by vneturngi into the uqarnaitne zone for the greatest ehits erve.</td>
#       <td id="T_c0c26_row1_col1" class="data row1 col1" >After a zombie outbreak in Las Vegas, a group of mercenaries takes the ultimate gamble by venturing into the quarantine zone for the greatest heist ever.</td>
#     </tr>
#     <tr>
#       <th id="T_c0c26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c0c26_row2_col0" class="data row2 col0" >As the war between avpmiers and Lycans rages on, Seelen waaksen from a prolonged, ofcred cryogenic sleep to afec a ahrrowing new enmye mhuans.</td>
#       <td id="T_c0c26_row2_col1" class="data row2 col1" >As the war between vampires and Lycans rages on, Selene awakens from a prolonged, forced cryogenic sleep to face a harrowing new enemy humans.</td>
#     </tr>
#     <tr>
#       <th id="T_c0c26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c0c26_row3_col0" class="data row3 col0" >Grvieign afrte a rtagdye, Malcoml tries to strta fresh iwht his new girlfriend and her kids but upsenratuarl shenaniagsn find their way bkac to him.</td>
#       <td id="T_c0c26_row3_col1" class="data row3 col1" >Grieving after a tragedy, Malcolm tries to start fresh with his new girlfriend and her kids  but supernatural shenanigans find their way back to him.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_char_random(pluto.df_twitter_data, action='insert', 
  col_dest='clean_tweet', aug_name='Random Insert Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_3a8af th {
#   font-size: 20px;
# }
# #T_3a8af td {
#   font-size: 18px;
# }
# </style>
# <table id="T_3a8af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a8af_level0_col0" class="col_heading level0 col0" >Random Insert Augment</th>
#       <th id="T_3a8af_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a8af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a8af_row0_col0" class="data row0 col0" >It was the bWe$st of tti%mes. It was the Dwborst of timyeGs. It was the age of wPi+sdom. It was the age of BfoolwishneysBs. It was the epSoc9h of bel1ie@f. It was the expoxch of +incr#ed+ulDity.</td>
#       <td id="T_3a8af_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_3a8af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a8af_row1_col0" class="data row1 col0" >no bmaatter how hard &l2ife ngKets. .. an(o^n # 7insepirUatioCn # gratwi+tlude # quote # inspirational</td>
#       <td id="T_3a8af_row1_col1" class="data row1 col1" >no matter how hard life gets... anon #inspiration #gratitude #quote #inspirational</td>
#     </tr>
#     <tr>
#       <th id="T_3a8af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a8af_row2_col0" class="data row2 col0" >you miAg0ht be a liJbmtarvd if. .. # lidbgtadrd # sjw # lgi(berbal # poalKiHtics</td>
#       <td id="T_3a8af_row2_col1" class="data row2 col1" >you might be a libtard if... #libtard #sjw #liberal #politics</td>
#     </tr>
#     <tr>
#       <th id="T_3a8af_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a8af_row3_col0" class="data row3 col0" >so in WlesZs tuhVan a Ay+ear these Hki)ds logsKt both yparteonts! wow! may god give them the styre&ng$th to go thr^oeugah this</td>
#       <td id="T_3a8af_row3_col1" class="data row3 col1" >so in less than a year these kids lost both parents! wow! may god give them the strength to go through this</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_char_random(pluto.df_twitter_data, action='delete', 
  col_dest='clean_tweet', aug_name='Random Delete Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_a8c80 th {
#   font-size: 20px;
# }
# #T_a8c80 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_a8c80" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8c80_level0_col0" class="col_heading level0 col0" >Random Delete Augment</th>
#       <th id="T_a8c80_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8c80_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8c80_row0_col0" class="data row0 col0" >It was the bs of ime. It was the wst of tms. It was the age of idom. It was the age of olisnes. It was the och of elie. It was the pch of icredul.</td>
#       <td id="T_a8c80_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_a8c80_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8c80_row1_col0" class="data row1 col0" >@ er bhda pkn 9 days to go @ user @ user @ us @ ur @ ur @ er</td>
#       <td id="T_a8c80_row1_col1" class="data row1 col1" >@user bihday pkn 9 days to go @user @user @user @user @user @user</td>
#     </tr>
#     <tr>
#       <th id="T_a8c80_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a8c80_row2_col0" class="data row2 col0" >@ se th lectn is mad proof of how lai ole rotten stupid pple rely are. .. . # raly # helaupi</td>
#       <td id="T_a8c80_row2_col1" class="data row2 col1" >@user this election is mad proof of how plain ole rotten  stupid people really are.... #really #hellastupid</td>
#     </tr>
#     <tr>
#       <th id="T_a8c80_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a8c80_row3_col0" class="data row3 col0" >in my feegs</td>
#       <td id="T_a8c80_row3_col1" class="data row3 col1" >in my feelings</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_char_random(pluto.df_twitter_data, action='substitute', 
  col_dest='clean_tweet', aug_name='Random Substitute Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_da9ce th {
#   font-size: 20px;
# }
# #T_da9ce td {
#   font-size: 18px;
# }
# </style>
# <table id="T_da9ce" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da9ce_level0_col0" class="col_heading level0 col0" >Random Substitute Augment</th>
#       <th id="T_da9ce_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da9ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da9ce_row0_col0" class="data row0 col0" >It was the 1es3 of tvmeU. It was the Moest of tim#e. It was the age of wisd6H. It was the age of fCDlFshnTss. It was the egoqh of bel0ep. It was the 9po^h of g0cheduli@y.</td>
#       <td id="T_da9ce_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_da9ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da9ce_row1_col0" class="data row1 col0" >8itY my WrlenKs sup$9 loHhly mom! # 2oge # fun # 87td # me # smile # 10viday # Vuse # la # tbt</td>
#       <td id="T_da9ce_row1_col1" class="data row1 col1" >with my friends super lovely mom! #love #fun #ootd #me #smile #holiday #cute #la #tbt</td>
#     </tr>
#     <tr>
#       <th id="T_da9ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da9ce_row2_col0" class="data row2 col0" ># Wiml&nd cHns*mMr pr2ci index yoy unqhaCgsd at 0. 3 in may # (lsg # silver # go#* # fjred</td>
#       <td id="T_da9ce_row2_col1" class="data row2 col1" >#finland consumer price index yoy unchanged at 0.3 in may #blog #silver #gold #forex</td>
#     </tr>
#     <tr>
#       <th id="T_da9ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da9ce_row3_col0" class="data row3 col0" >@ IsMr @ u0or well done D3lly on (eQpinY ykzr carm whh8e talking to that lyd3 with 12 kiNu, 40, 000 i wish amp i Bor^</td>
#       <td id="T_da9ce_row3_col1" class="data row3 col1" >@user @user well done holly on keeping your carm while talking to that lady with 12 kids,40,000 i wish amp i work</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_char_random(pluto.df_twitter_data, action='swap', 
  col_dest='clean_tweet', aug_name='Random Swap Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_85ebf th {
#   font-size: 20px;
# }
# #T_85ebf td {
#   font-size: 18px;
# }
# </style>
# <table id="T_85ebf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85ebf_level0_col0" class="col_heading level0 col0" >Random Swap Augment</th>
#       <th id="T_85ebf_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85ebf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85ebf_row0_col0" class="data row0 col0" >It was the best of itmse. It was the rwost of mties. It was the age of wsiodm. It was the age of fooilshnses. It was the eophc of beielf. It was the peohc of inrceuditly.</td>
#       <td id="T_85ebf_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_85ebf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_85ebf_row1_col0" class="data row1 col0" >akte me to nevreldan. .. # mreyrgoruodn # draeym # ohsre # wooden # woondheosre</td>
#       <td id="T_85ebf_row1_col1" class="data row1 col1" >take me to neverland... #merrygoround #dreamy #horse #wooden #woodenhorse</td>
#     </tr>
#     <tr>
#       <th id="T_85ebf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_85ebf_row2_col0" class="data row2 col0" >ovle me omse toy swsap! # momtips</td>
#       <td id="T_85ebf_row2_col1" class="data row2 col1" >love me some toy swaps! #momtips</td>
#     </tr>
#     <tr>
#       <th id="T_85ebf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_85ebf_row3_col0" class="data row3 col0" ># afthresady to my # beloved baby # rbtoehr! i know ppaa is vyer # oprud of what a # owndreflu</td>
#       <td id="T_85ebf_row3_col1" class="data row3 col1" >#fathersday to my #beloved baby #brother! i know papa is very #proud of what a #wonderful</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Word augmentation

# %% [markdown]
# ## Misspell Augmenter<a class="anchor" id="spelling_aug"></a>

# %% [markdown]
# - Substitute word by spelling mistake words dictionary

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_word_misspell(self, df, col_dest="description",bsize=3, aug_name='Augment'):
  aug_func = nlpaug.augmenter.word.SpellingAug()
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_word_misspell(pluto.df_netflix_data, 
  col_dest='description', aug_name='Word Spelling Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_ec388 th {
#   font-size: 20px;
# }
# #T_ec388 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_ec388" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec388_level0_col0" class="col_heading level0 col0" >Word Spelling Augment</th>
#       <th id="T_ec388_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec388_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec388_row0_col0" class="data row0 col0" >Ir was the best of tames. It was the worst of times. IT was the age of wisdoms. It was Then ago of foolishness. I was the epoch oof belief. lt was the epoch os incredulity.</td>
#       <td id="T_ec388_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_ec388_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ec388_row1_col0" class="data row1 col0" >French rap duo PNL deliever hypnotic visuals and parfum popular tracks form the album Dans la lgende anr mare at the Bercy Arena hs paeis.</td>
#       <td id="T_ec388_row1_col1" class="data row1 col1" >French rap duo PNL deliver hypnotic visuals and perform popular tracks from their album Dans la lgende and more at the Bercy Arena in Paris.</td>
#     </tr>
#     <tr>
#       <th id="T_ec388_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ec388_row2_col0" class="data row2 col0" >A yough woman tracks down their older mom who prayed on her a and child, forcing theem both to confront the damage done my what happens 15.oo years earlier.</td>
#       <td id="T_ec388_row2_col1" class="data row2 col1" >A young woman tracks down the older man who preyed on her as a child, forcing them both to confront the damage done by what happened 15 years earlier.</td>
#     </tr>
#     <tr>
#       <th id="T_ec388_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ec388_row3_col0" class="data row3 col0" >A devastating breakup with her boyfriend My b tnhe start oh al neu beginning fou Mace, thnx to an adventurous and kind strenger named Anthony.</td>
#       <td id="T_ec388_row3_col1" class="data row3 col1" >A devastating breakup with her boyfriend may be the start of a new beginning for Mace, thanks to an adventurous and kind stranger named Anthony.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_misspell(pluto.df_twitter_data, 
  col_dest='clean_tweet', aug_name='Word Spelling Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_18cd4 th {
#   font-size: 20px;
# }
# #T_18cd4 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_18cd4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18cd4_level0_col0" class="col_heading level0 col0" >Word Spelling Augment</th>
#       <th id="T_18cd4_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18cd4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18cd4_row0_col0" class="data row0 col0" >It has thhe besr of times. I'ts has the wost of times. It was the age of wisdoms. It was the age of foolishness. It wsa thel epoch of belief. It was the epoch og incredulity.</td>
#       <td id="T_18cd4_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_18cd4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_18cd4_row1_col0" class="data row1 col0" >@ user hillarious, @ user I already blocked bye @ user fore aksing ano, nor paicularly difficoult, question. @ user</td>
#       <td id="T_18cd4_row1_col1" class="data row1 col1" >@user hilarious, @user im already blocked by @user for asking one, not paicularly difficult, question. @user</td>
#     </tr>
#     <tr>
#       <th id="T_18cd4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_18cd4_row2_col0" class="data row2 col0" ># drakeandjosh buffalo simulation buffalo four yu tho take no the vicinity of tey homes to do. EN thi's wa</td>
#       <td id="T_18cd4_row2_col1" class="data row2 col1" >#drakeandjosh buffalo simulation buffalo for you to take in the vicinity of their homes to do. in this wa</td>
#     </tr>
#     <tr>
#       <th id="T_18cd4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_18cd4_row3_col0" class="data row3 col0" >@ user saw sads that a fellow # studdent from my # university # angliaruskin hase seen taken frrom us. # thoughts are witc him # femaly # rip</td>
#       <td id="T_18cd4_row3_col1" class="data row3 col1" >@user so sad that a fellow #student from my #university #angliaruskin has been taken from us. #thoughts are with his #family #rip</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Split Augmenter<a class="anchor" id="split_aug"></a>

# %% [markdown]
# - Split word to two tokens randomly

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_word_split(self, df, col_dest="description",bsize=3, aug_name='Augment'):
  aug_func = nlpaug.augmenter.word.SplitAug()
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_word_split(pluto.df_netflix_data, col_dest='description', aug_name='Word Split Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_b8f14 th {
#   font-size: 20px;
# }
# #T_b8f14 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_b8f14" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8f14_level0_col0" class="col_heading level0 col0" >Word Split Augment</th>
#       <th id="T_b8f14_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8f14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8f14_row0_col0" class="data row0 col0" >It was the be st of tim es. It was the wo rst of tim es. It was the age of wis dom. It was the age of foolishn ess. It was the epo ch of b elief. It was the e poch of incre dulity.</td>
#       <td id="T_b8f14_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_b8f14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b8f14_row1_col0" class="data row1 col0" >Nar uto, Sasu ke and Sak ura l earn t heyll be protect ing an actress from b eing hurt whi le ma king her next film, but it turns out shes a princess.</td>
#       <td id="T_b8f14_row1_col1" class="data row1 col1" >Naruto, Sasuke and Sakura learn theyll be protecting an actress from being hurt while making her next film, but it turns out shes a princess.</td>
#     </tr>
#     <tr>
#       <th id="T_b8f14_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b8f14_row2_col0" class="data row2 col0" >The Fab Five to uch d own in Tok yo to s pread the joy, explore the cult ure, and help four Jap anese men and women f ind the confiden ce to be them selves.</td>
#       <td id="T_b8f14_row2_col1" class="data row2 col1" >The Fab Five touch down in Tokyo to spread the joy, explore the culture, and help four Japanese men and women find the confidence to be themselves.</td>
#     </tr>
#     <tr>
#       <th id="T_b8f14_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b8f14_row3_col0" class="data row3 col0" >Follow the M urphy family back to the 197 0s, w hen ki ds roam ed wild, beer fl owed f reely and nothing ca me be tween a man and his TV.</td>
#       <td id="T_b8f14_row3_col1" class="data row3 col1" >Follow the Murphy family back to the 1970s, when kids roamed wild, beer flowed freely and nothing came between a man and his TV.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_split(pluto.df_twitter_data, col_dest='clean_tweet', aug_name='Word Split Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_08378 th {
#   font-size: 20px;
# }
# #T_08378 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_08378" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08378_level0_col0" class="col_heading level0 col0" >Word Split Augment</th>
#       <th id="T_08378_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08378_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08378_row0_col0" class="data row0 col0" >It was the be st of t imes. It was the wor st of ti mes. It was the age of w isdom. It was the age of foo lishness. It was the ep och of bel ief. It was the e poch of inc redulity.</td>
#       <td id="T_08378_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_08378_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08378_row1_col0" class="data row1 col0" >tdc med ia @ us er amp @ u ser mu st be con fused @ us er of cou rse it was a hate cr ime. .. a # radicalislamicterrorist attack a gainst # usa</td>
#       <td id="T_08378_row1_col1" class="data row1 col1" >tdc media @user amp @user must be confused @user of course it was a hate crime...a #radicalislamicterrorist attack against #usa</td>
#     </tr>
#     <tr>
#       <th id="T_08378_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_08378_row2_col0" class="data row2 col0" >beware the sno wball e ffect blackm an! pa 2</td>
#       <td id="T_08378_row2_col1" class="data row2 col1" >beware the snowball effect blackman! pa 2</td>
#     </tr>
#     <tr>
#       <th id="T_08378_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_08378_row3_col0" class="data row3 col0" >oh boy! ! r eunited and it fee ls so g ood! # 2 sisters # bae # tim eless # beau ty # sistersist er</td>
#       <td id="T_08378_row3_col1" class="data row3 col1" >oh boy!! reunited and it feels so good!#2sisters #bae #timeless #beauty #sistersister</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Random Word Augmenter

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_word_random(self, df, action='swap', col_dest="description",bsize=3, aug_name='Augment'):
  aug_func = nlpaug.augmenter.word.RandomWordAug(action=action)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_word_random(pluto.df_netflix_data, action='swap', 
  col_dest='description', aug_name='Word Random Swap Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_4d3b0 th {
#   font-size: 20px;
# }
# #T_4d3b0 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_4d3b0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d3b0_level0_col0" class="col_heading level0 col0" >Word Random Swap Augment</th>
#       <th id="T_4d3b0_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d3b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d3b0_row0_col0" class="data row0 col0" >It the was best of times. It was the of worst times was. It the age of wisdom. It was the age of foolishness It. was epoch the of belief. It was the epoch of incredulity.</td>
#       <td id="T_4d3b0_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_4d3b0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4d3b0_row1_col0" class="data row1 col0" >Jake and brothers Will travel Grimm village from to village, posing exterminators as of creatures magical. But reality in, theyre expert con artists.</td>
#       <td id="T_4d3b0_row1_col1" class="data row1 col1" >Brothers Jake and Will Grimm travel from village to village, posing as exterminators of magical creatures. But in reality, theyre expert con artists.</td>
#     </tr>
#     <tr>
#       <th id="T_4d3b0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4d3b0_row2_col0" class="data row2 col0" >Armed with healthy a sense humor of and help the his of teacher friends, and family, kid curious Sid tackles youngsters have questions science about.</td>
#       <td id="T_4d3b0_row2_col1" class="data row2 col1" >Armed with a healthy sense of humor and the help of his teacher, friends and family, curious kid Sid tackles questions youngsters have about science.</td>
#     </tr>
#     <tr>
#       <th id="T_4d3b0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4d3b0_row3_col0" class="data row3 col0" >A by framed politician for committing murder, a lowerclass boy hires the counsel he only can a afford with lawyer no experience courtroom.</td>
#       <td id="T_4d3b0_row3_col1" class="data row3 col1" >Framed by a politician for committing murder, a lowerclass boy hires the only counsel he can afford a lawyer with no courtroom experience.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_random(pluto.df_twitter_data, action='swap', 
  col_dest='clean_tweet', aug_name='Word Random Swap Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_f76e2 th {
#   font-size: 20px;
# }
# #T_f76e2 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_f76e2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f76e2_level0_col0" class="col_heading level0 col0" >Word Random Swap Augment</th>
#       <th id="T_f76e2_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f76e2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f76e2_row0_col0" class="data row0 col0" >Was it the best of times. It the was worst times of. It was the age of wisdom It. was the age of foolishness. It the was belief epoch of. It was epoch the of incredulity.</td>
#       <td id="T_f76e2_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_f76e2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f76e2_row1_col0" class="data row1 col0" >poor souls minions # # lol darkness # hellodarknessmyoldfriend #</td>
#       <td id="T_f76e2_row1_col1" class="data row1 col1" >poor souls #minions #lol #darkness #hellodarknessmyoldfriend</td>
#     </tr>
#     <tr>
#       <th id="T_f76e2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f76e2_row2_col0" class="data row2 col0" >Gop # will on fail antimorality. platform</td>
#       <td id="T_f76e2_row2_col1" class="data row2 col1" >#gop will fail on antimorality platform.</td>
#     </tr>
#     <tr>
#       <th id="T_f76e2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f76e2_row3_col0" class="data row3 col0" >@ user @ user @ user this is i how to spnd fathers day wanted wknd wboy, n grilln chilln.</td>
#       <td id="T_f76e2_row3_col1" class="data row3 col1" >@user @user @user this is how i wanted to spnd fathers day wknd, wboy grilln n chilln.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_random(pluto.df_netflix_data, action='substitute', 
  col_dest='description', aug_name='Word Random Substitude Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_27130 th {
#   font-size: 20px;
# }
# #T_27130 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_27130" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27130_level0_col0" class="col_heading level0 col0" >Word Random Substitude Augment</th>
#       <th id="T_27130_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27130_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27130_row0_col0" class="data row0 col0" >_ was the best of times. It was _ worst of _. _ _ the age of _. It was the _ of foolishness. It was _ _ _ belief. It was the epoch of incredulity.</td>
#       <td id="T_27130_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_27130_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_27130_row1_col0" class="data row1 col0" >_ _ excon _ his unhinged former _ for _ last job kidnap the baby _ a mobsters enemy _ ransom.</td>
#       <td id="T_27130_row1_col1" class="data row1 col1" >A delusional excon rejoins his unhinged former partners for one last job kidnap the baby of a mobsters enemy for ransom.</td>
#     </tr>
#     <tr>
#       <th id="T_27130_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_27130_row2_col0" class="data row2 col0" >Three friends who study martial _ find _ defending _ from _ _ _ and his invading army from another _.</td>
#       <td id="T_27130_row2_col1" class="data row2 col1" >Three friends who study martial arts find themselves defending humanity from a criminal mastermind and his invading army from another dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_27130_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_27130_row3_col0" class="data row3 col0" >Comedians Jimmy Carr, D. L. Hughley and _ Ryan tackle the _ _ with _ _ _ rotating _ of funny guests _ an _ expert.</td>
#       <td id="T_27130_row3_col1" class="data row3 col1" >Comedians Jimmy Carr, D.L. Hughley and Katherine Ryan tackle the worlds woes with help from a rotating crew of funny guests and an actual expert.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_random(pluto.df_twitter_data, action='substitute', 
  col_dest='clean_tweet', aug_name='Word Random Substitute Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_af101 th {
#   font-size: 20px;
# }
# #T_af101 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_af101" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af101_level0_col0" class="col_heading level0 col0" >Word Random Substitute Augment</th>
#       <th id="T_af101_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af101_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_af101_row0_col0" class="data row0 col0" >It was the best of times. _ was the _ of _. It was the age _ wisdom. It was the _ of foolishness. _ was the _ _ _. It was the epoch of _.</td>
#       <td id="T_af101_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_af101_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_af101_row1_col0" class="data row1 col0" >_ _ at my first job</td>
#       <td id="T_af101_row1_col1" class="data row1 col1" >got hired at my first job</td>
#     </tr>
#     <tr>
#       <th id="T_af101_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_af101_row2_col0" class="data row2 col0" >smile, its _ _! ! # _ # _ # wildwood</td>
#       <td id="T_af101_row2_col1" class="data row2 col1" >smile, its the weekend!! #weekendsmiles #mydubai #wildwood</td>
#     </tr>
#     <tr>
#       <th id="T_af101_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_af101_row3_col0" class="data row3 col0" >@ _ # 711 _ _ # sharkweek _ or _ _ # slurpees # scubadiver. # simplejoys # _</td>
#       <td id="T_af101_row3_col1" class="data row3 col1" >@user #711 had no #sharkweek straws or cups for #slurpees #scubadiver. #simplejoys #nothappy</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_random(pluto.df_netflix_data, action='crop', 
  col_dest='description', aug_name='Word Random Crop Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_c568c th {
#   font-size: 20px;
# }
# #T_c568c td {
#   font-size: 18px;
# }
# </style>
# <table id="T_c568c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c568c_level0_col0" class="col_heading level0 col0" >Word Random Crop Augment</th>
#       <th id="T_c568c_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c568c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c568c_row0_col0" class="data row0 col0" >It was the best of times. It was the. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_c568c_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_c568c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c568c_row1_col0" class="data row1 col0" >A suburban dad having a midlife crisis his punkrock past but discovers its not easy going back.</td>
#       <td id="T_c568c_row1_col1" class="data row1 col1" >A suburban dad having a midlife crisis throws a lavish 40th birthday party to celebrate his punkrock past but discovers its not easy going back.</td>
#     </tr>
#     <tr>
#       <th id="T_c568c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c568c_row2_col0" class="data row2 col0" >Years after they elope against sons become caught in the throes of conflict in their city.</td>
#       <td id="T_c568c_row2_col1" class="data row2 col1" >Years after they elope against their familys wishes, a couple and their sons become caught in the throes of conflict in their city.</td>
#     </tr>
#     <tr>
#       <th id="T_c568c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c568c_row3_col0" class="data row3 col0" >This a circus elephant attacked and killed its trainer, then ran loose on the city streets.</td>
#       <td id="T_c568c_row3_col1" class="data row3 col1" >This documentary recounts a 1994 incident in Honolulu in which a circus elephant attacked and killed its trainer, then ran loose on the city streets.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_random(pluto.df_twitter_data, action='crop', 
  col_dest='clean_tweet', aug_name='Word Random Crop Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_3a902 th {
#   font-size: 20px;
# }
# #T_3a902 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_3a902" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a902_level0_col0" class="col_heading level0 col0" >Word Random Crop Augment</th>
#       <th id="T_3a902_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a902_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a902_row0_col0" class="data row0 col0" >It was the best of times. It of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_3a902_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_3a902_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a902_row1_col0" class="data row1 col0" >having naked arabian</td>
#       <td id="T_3a902_row1_col1" class="data row1 col1" >couple having  naked arabian</td>
#     </tr>
#     <tr>
#       <th id="T_3a902_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a902_row2_col0" class="data row2 col0" >@ user fathers day</td>
#       <td id="T_3a902_row2_col1" class="data row2 col1" >@user @user fathers day</td>
#     </tr>
#     <tr>
#       <th id="T_3a902_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a902_row3_col0" class="data row3 col0" >happiness is seeing your friend trapped marriage</td>
#       <td id="T_3a902_row3_col1" class="data row3 col1" >happiness is seeing your friend trapped in the name of marriage</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_random(pluto.df_netflix_data, action='delete', 
  col_dest='description', aug_name='Word Random Delete Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_1342e th {
#   font-size: 20px;
# }
# #T_1342e td {
#   font-size: 18px;
# }
# </style>
# <table id="T_1342e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1342e_level0_col0" class="col_heading level0 col0" >Word Random Delete Augment</th>
#       <th id="T_1342e_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1342e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1342e_row0_col0" class="data row0 col0" >Was the best times. was the worst of times. was the of wisdom. It of foolishness. It the epoch of. It was the epoch of incredulity.</td>
#       <td id="T_1342e_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_1342e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1342e_row1_col0" class="data row1 col0" >Discovering to a ancient order, a man living Istanbul embarks on a quest to save city from an.</td>
#       <td id="T_1342e_row1_col1" class="data row1 col1" >Discovering his ties to a secret ancient order, a young man living in modern Istanbul embarks on a quest to save the city from an immortal enemy.</td>
#     </tr>
#     <tr>
#       <th id="T_1342e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1342e_row2_col0" class="data row2 col0" >When discrimination prevents from giving his father a rightful, takes his for equality to.</td>
#       <td id="T_1342e_row2_col1" class="data row2 col1" >When caste discrimination prevents a villager from giving his deceased father a rightful burial, he takes his fight for equality to court.</td>
#     </tr>
#     <tr>
#       <th id="T_1342e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1342e_row3_col0" class="data row3 col0" >When swarm soulstealing invades moon, group of elite space Marines must obliterate the save Earth.</td>
#       <td id="T_1342e_row3_col1" class="data row3 col1" >When a swarm of soulstealing demons invades a Martian moon, a group of elite space Marines must obliterate the beasts to save Earth.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_random(pluto.df_twitter_data, action='delete', 
  col_dest='clean_tweet', aug_name='Word Random Delete Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_b563e th {
#   font-size: 20px;
# }
# #T_b563e td {
#   font-size: 18px;
# }
# </style>
# <table id="T_b563e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b563e_level0_col0" class="col_heading level0 col0" >Word Random Delete Augment</th>
#       <th id="T_b563e_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b563e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b563e_row0_col0" class="data row0 col0" >Was the best of times. It was the worst of times. It the age of. the age. It the of belief. It was the epoch of.</td>
#       <td id="T_b563e_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_b563e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b563e_row1_col0" class="data row1 col0" >my my joy, thank the. .. .. .. fathers</td>
#       <td id="T_b563e_row1_col1" class="data row1 col1" >my kids are my joy, thank the almighty everyday for them.......fathers love</td>
#     </tr>
#     <tr>
#       <th id="T_b563e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b563e_row2_col0" class="data row2 col0" >i angelic. # # # affirmation</td>
#       <td id="T_b563e_row2_col1" class="data row2 col1" >i am angelic. #iam #positive #affirmation</td>
#     </tr>
#     <tr>
#       <th id="T_b563e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b563e_row3_col0" class="data row3 col0" ># buffalo simulation buffalo you in the vicinity of homes do. in way, you</td>
#       <td id="T_b563e_row3_col1" class="data row3 col1" >#broken buffalo simulation buffalo for you to take in the vicinity of their homes to do. in this way, you</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Synonym Augmenter

# %%
# %%writefile -a {pluto_chapter_5}

nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# - Substitute word by WordNet's synonym

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_word_synonym(self, df, col_dest="description",bsize=3, aug_name='Augment'):
  aug_func = nlpaug.augmenter.word.SynonymAug(aug_src='wordnet')
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_word_synonym(pluto.df_netflix_data, 
  col_dest='description', aug_name='Synonym WordNet Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_26b94 th {
#   font-size: 20px;
# }
# #T_26b94 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_26b94" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26b94_level0_col0" class="col_heading level0 col0" >Synonym WordNet Augment</th>
#       <th id="T_26b94_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26b94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26b94_row0_col0" class="data row0 col0" >It was the best of time. It was the worst of times. It was the age of wisdom. Information technology be the age of foolishness. Information technology was the date of reference of impression. Information technology was the epoch of mental rejection.</td>
#       <td id="T_26b94_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_26b94_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26b94_row1_col0" class="data row1 col0" >After a pair of shirker dress up as policeman for a costume party, they adjudicate to prolong their disguise not knowing that it will extend them to danger.</td>
#       <td id="T_26b94_row1_col1" class="data row1 col1" >After a duo of slackers dress up as policemen for a costume party, they decide to prolong their disguise  not knowing that it will lead them to danger.</td>
#     </tr>
#     <tr>
#       <th id="T_26b94_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26b94_row2_col0" class="data row2 col0" >To get away from the thug life, cocain dealer Youngblood Priest put unitedly one concluding deal that will net him enough money to commence all over.</td>
#       <td id="T_26b94_row2_col1" class="data row2 col1" >To get away from the thug life, cocaine dealer Youngblood Priest puts together one last deal that will net him enough money to start over.</td>
#     </tr>
#     <tr>
#       <th id="T_26b94_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26b94_row3_col0" class="data row3 col0" >Two veteran drug dealer return to the spunky streets of London, but their pursuit of money and power exist peril by a new and ruthless hustler.</td>
#       <td id="T_26b94_row3_col1" class="data row3 col1" >Two seasoned drug dealers return to the gritty streets of London, but their pursuit of money and power is threatened by a young and ruthless hustler.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_synonym(pluto.df_twitter_data, 
  col_dest='clean_tweet', aug_name='Synonym WordNet Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_eef3b th {
#   font-size: 20px;
# }
# #T_eef3b td {
#   font-size: 18px;
# }
# </style>
# <table id="T_eef3b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eef3b_level0_col0" class="col_heading level0 col0" >Synonym WordNet Augment</th>
#       <th id="T_eef3b_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eef3b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eef3b_row0_col0" class="data row0 col0" >It was the best of times. It was the worst of time. Information technology was the old age of wisdom. Information technology personify the age of imbecility. Information technology was the epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_eef3b_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_eef3b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eef3b_row1_col0" class="data row1 col0" >@ user its just now amp my opinion</td>
#       <td id="T_eef3b_row1_col1" class="data row1 col1" >@user its just amp my opinion</td>
#     </tr>
#     <tr>
#       <th id="T_eef3b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eef3b_row2_col0" class="data row2 col0" ># udtapunjab in todays report. # bjp, no one is # defamingpunjab its already defamed. awake upwards, it never to a fault late</td>
#       <td id="T_eef3b_row2_col1" class="data row2 col1" >#udtapunjab in todays paper. #bjp , no one is #defamingpunjab its already defamed. wake up,its never too late</td>
#     </tr>
#     <tr>
#       <th id="T_eef3b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eef3b_row3_col0" class="data row3 col0" >what is becoming of this talented motion picture maker? @ user be turn into a political flunky of # aap!</td>
#       <td id="T_eef3b_row3_col1" class="data row3 col1" >what is becoming of this talented film maker ? @user is turning into a political stooge of #aap !</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Antonym Augmenter<a class="anchor" id="antonym_aug"></a>

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_word_antonym(self, df, col_dest="description",bsize=3, aug_name='Augment'):
  aug_func = nlpaug.augmenter.word.AntonymAug()
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_word_antonym(pluto.df_netflix_data, 
  col_dest='description',aug_name='Antonym Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_63f70 th {
#   font-size: 20px;
# }
# #T_63f70 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_63f70" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63f70_level0_col0" class="col_heading level0 col0" >Antonym Augment</th>
#       <th id="T_63f70_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63f70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63f70_row0_col0" class="data row0 col0" >It differ the worst of times. It differ the unregretful of times. It differ the age of wisdom. It differ the age of foolishness. It differ the epoch of belief. It differ the epoch of incredulity.</td>
#       <td id="T_63f70_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_63f70_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_63f70_row1_col0" class="data row1 col0" >After take away their hands on a misdirected shipment of cell phones, two hustlers try to cash in by hawking the merchandise from the back of their van.</td>
#       <td id="T_63f70_row1_col1" class="data row1 col1" >After getting their hands on a misdirected shipment of cell phones, two hustlers try to cash in by hawking the merchandise from the back of their van.</td>
#     </tr>
#     <tr>
#       <th id="T_63f70_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_63f70_row2_col0" class="data row2 col0" >A stressedout documentary filmmaker stay in place on a journey of discovery with a pair of monks, one of whom differ ignore as the unhappy man in the world.</td>
#       <td id="T_63f70_row2_col1" class="data row2 col1" >A stressedout documentary filmmaker goes on a journey of discovery with a pair of monks, one of whom is known as the happiest man in the world.</td>
#     </tr>
#     <tr>
#       <th id="T_63f70_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_63f70_row3_col0" class="data row3 col0" >High TV ratings attract a wellknown journalist to concoct a plan to interview a notorious underworld figure who differ also a unsuspected terrorist.</td>
#       <td id="T_63f70_row3_col1" class="data row3 col1" >Low TV ratings drive a wellknown journalist to concoct a plan to interview a notorious underworld figure who is also a suspected terrorist.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_word_antonym(pluto.df_twitter_data, 
  col_dest='clean_tweet',aug_name='Antonym Augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_d0fe0 th {
#   font-size: 20px;
# }
# #T_d0fe0 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_d0fe0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0fe0_level0_col0" class="col_heading level0 col0" >Antonym Augment</th>
#       <th id="T_d0fe0_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0fe0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0fe0_row0_col0" class="data row0 col0" >It differ the bad of times. It differ the unregretful of times. It differ the age of wisdom. It differ the age of foolishness. It differ the epoch of belief. It differ the epoch of incredulity.</td>
#       <td id="T_d0fe0_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_d0fe0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0fe0_row1_col0" class="data row1 col0" >abstain a very bad salty dreams everyone and tomorrow # tuesday # bynight # smile</td>
#       <td id="T_d0fe0_row1_col1" class="data row1 col1" >have a very good sweet dreams everyone and tomorrow #tuesday #bynight #smile</td>
#     </tr>
#     <tr>
#       <th id="T_d0fe0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0fe0_row2_col0" class="data row2 col0" >atypical egotistical # tweet from @ user # pathetic</td>
#       <td id="T_d0fe0_row2_col1" class="data row2 col1" >typical egotistical #tweet from @user #pathetic</td>
#     </tr>
#     <tr>
#       <th id="T_d0fe0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0fe0_row3_col0" class="data row3 col0" >unhappy friday! !! ! friday # laugh # comedy # cats # women # she</td>
#       <td id="T_d0fe0_row3_col1" class="data row3 col1" >happy friday!!!! friday #laugh #comedy #cats #women #she</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Reserved Word Augmenter<a class="anchor" id="reserved_aug"></a>

# %%
# %%writefile -a {pluto_chapter_5}

@add_method(PacktDataAug)
def print_aug_word_reserved(self, df, col_dest="description",reserved_tokens=None,bsize=3, aug_name='Augment'):
  aug_func = nlpaug.augmenter.word.ReservedAug(reserved_tokens=reserved_tokens)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
# %%writefile -a {pluto_chapter_5}

pluto.reserved_control = [['wisdom', 'sagacity', 'intelligence', 'prudence'],
  ['foolishness', 'folly', 'idiocy', 'stupidity']]

# %%
# %%writefile -a {pluto_chapter_5}

pluto.reserved_netflix = [['family','household', 'brood', 'unit', 'families'],
  ['life','existance', 'entity', 'creation'],
  ['love', 'warmth', 'endearment','tenderness']]
pluto.reserved_netflix = pluto.reserved_control + pluto.reserved_netflix

# %%
pluto.print_aug_word_reserved(pluto.df_netflix_data, col_dest='description', 
  reserved_tokens=pluto.reserved_netflix, aug_name='Netflix Reserved word augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_2bdee th {
#   font-size: 20px;
# }
# #T_2bdee td {
#   font-size: 18px;
# }
# </style>
# <table id="T_2bdee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bdee_level0_col0" class="col_heading level0 col0" >Netflix Reserved word augment</th>
#       <th id="T_2bdee_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bdee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2bdee_row0_col0" class="data row0 col0" >It was the best of times. It was the worst of times. It was the age of sagacity. It was the age of idiocy. It was the epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_2bdee_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_2bdee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2bdee_row1_col0" class="data row1 col0" >The Rangers use hightech battle cars to take on Queen Divatox and her Divazords, who mount an attack on the Rangers beloved Angel Grove.</td>
#       <td id="T_2bdee_row1_col1" class="data row1 col1" >The Rangers use hightech battle cars to take on Queen Divatox and her Divazords, who mount an attack on the Rangers beloved Angel Grove.</td>
#     </tr>
#     <tr>
#       <th id="T_2bdee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2bdee_row2_col0" class="data row2 col0" >Pierce Brosnans final outing as 007 finds James Bond facing off against a North Korean terrorist whos in league with a British diamond merchant.</td>
#       <td id="T_2bdee_row2_col1" class="data row2 col1" >Pierce Brosnans final outing as 007 finds James Bond facing off against a North Korean terrorist whos in league with a British diamond merchant.</td>
#     </tr>
#     <tr>
#       <th id="T_2bdee_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2bdee_row3_col0" class="data row3 col0" >As the Medelln Cartel crumbles, Pablo Escobars No. 1 hit man struggles to stay alive and gain respect in the prison hierarchy.</td>
#       <td id="T_2bdee_row3_col1" class="data row3 col1" >As the Medelln Cartel crumbles, Pablo Escobars No. 1 hit man struggles to stay alive and gain respect in the prison hierarchy.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# %%writefile -a {pluto_chapter_5}

pluto.reserved_twitter = [['user', 'users', 'customer', 'client','people','member','shopper'],
  ['happy', 'cheerful', 'joyful', 'carefree'],
  ['time','clock','hour']]
pluto.reserved_twitter = pluto.reserved_control + pluto.reserved_twitter

# %%
# pluto.reserved_twitter

# %%
pluto.print_aug_word_reserved(pluto.df_twitter_data, col_dest='clean_tweet', 
  reserved_tokens=pluto.reserved_twitter,aug_name='Twitter Reserved word augment')
# Out:
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-43-3f4035bfface>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_ac987 th {
#   font-size: 20px;
# }
# #T_ac987 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_ac987" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac987_level0_col0" class="col_heading level0 col0" >Twitter Reserved word augment</th>
#       <th id="T_ac987_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac987_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac987_row0_col0" class="data row0 col0" >It was the best of times. It was the worst of times. It was the age of prudence. It was the age of folly. It was the epoch of belief. It was the epoch of incredulity.</td>
#       <td id="T_ac987_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_ac987_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac987_row1_col0" class="data row1 col0" >wish you were here with me, looking how i am and how #good you have done #job #hotel</td>
#       <td id="T_ac987_row1_col1" class="data row1 col1" >wish you were here with me, looking how i am and how #good you have done #job #hotel</td>
#     </tr>
#     <tr>
#       <th id="T_ac987_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac987_row2_col0" class="data row2 col0" >dear america. please dont let this influence your vote. trump is not the solution, nor will he ever be. #orlando #massshooting</td>
#       <td id="T_ac987_row2_col1" class="data row2 col1" >dear america. please dont let this influence your vote. trump is not the solution, nor will he ever be. #orlando #massshooting</td>
#     </tr>
#     <tr>
#       <th id="T_ac987_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac987_row3_col0" class="data row3 col0" >7 impoant things to allow the #child to be</td>
#       <td id="T_ac987_row3_col1" class="data row3 col1" >7 impoant things to allow the #child to be</td>
#     </tr>
#   </tbody>
# </table>

# %%
# end of chapter 5
print('End of chapter 5.')
# Out:
# End of chapter 5.

# %% [markdown]
# # Push up all changes (Optional)

# %% [markdown]
# - username: duchaba
#
# - password: [use the token]

# %%
# import os
# f = 'Data-Augmentation-with-Python'
# os.chdir(f)
# !git add -A
# !git config --global user.email "duc.haba@gmail.com"
# !git config --global user.name "duchaba"
# !git commit -m "end of session"
# # do the git push in the xterm console
# #!git push

# %%
# %%script false --no-raise-error  #temporary stop execute for export file

# %% [markdown]
# # Summary

# %% [markdown]
# Every chaper will begin with same base class "PacktDataAug".
#
# ✋ FAIR WARNING:
#
# - The coding uses long and complete function path name.
#
# - Pluto wrote the code for easy to understand and not for compactness, fast execution, nor cleaverness.
#
# - Use Xterm to debug cloud server

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
