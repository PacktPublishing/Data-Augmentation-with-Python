# %% [markdown]
# <a href="https://colab.research.google.com/github/duchaba/Data-Augmentation-with-Python/blob/main/data_augmentation_with_python_chapter_6_with_output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌻 Welcome to Chapter 6, Text Augmentation with Machine Learning
#
#
# ---
#
# I am glad to see you using this Python Notebook. 🐶
#
# The Python Notebook is an integral part of the book. You can add new “code cells” to extend the functions, add your data, and explore new possibilities, such as downloading additional real-world datasets from the Kaggle website and coding the **Fun challenges**. Furthermore, the book has **Fun facts**, in-depth discussion about augmentation techniques, and Pluto, an imaginary Siberian Huskey coding companion. Together they will guide you every steps of the way.
#
# Pluto encourages you to copy or save a copy of this Python Notebook to your local space and add the “text cells” to keep your notes. In other words, read the book and copy the relevant concept to this Python Notebook’s text-cells. Thus, you can have the explanation, note, original code, your code, and any crazy future ideas in one place.
#
#
# 💗 I hope you enjoy reading the book and hacking code as much as I enjoy writing it.
#
#
# ## 🌟 Amazon Book
#
# ---
#
# - The book is available on the Amazon Book website:
#   - https://www.amazon.com/dp/1803246456
#
#   - Author: Duc Haba
#   - Published: 2023
#   - Page count: 390+
#
#
# - The original Python Notebook is on:
#   - https://github.com/PacktPublishing/Data-Augmentation-with-Python/blob/main/Chapter_6/data_augmentation_with_python_chapter_6.ipynb
#
# - 🚀 Click on the blue "Open in Colab" button at the top of this page to begin hacking.

# %% [markdown]
# # 😀 Excerpt from Chapter 6, Text Augmentation with Machine Learning
#
# ---
#
# > In case you haven’t bought the book. Here is an teaser from the first page of Chapter 6.
#
# ---
#
# Text augmentation with machine learning (ML) is an advanced technique compared to the standard text augmenting methods we covered in the previous chapter. Ironically, text augmentation aims to improve ML model accuracy, but we used a pre-trained ML model to create additional training NLP data. It’s a circular process. ML coding is not in this book’s scope, but understanding the difference between using libraries and ML for text augmentation is beneficial.
#
# Augmentation libraries, whether for image, text, or audio, follow the traditional programming methodologies with structure data, loops, and conditional statements in the algorithm. For example, as shown in Chapter 5, the pseudocode for implementing the _print_aug_reserved() method could be as follows:
#
# ```
# # define synonym words, pseudo-code
#
# reserved = [['happy', 'joyful', 'cheerful'],
#   ['sad', 'sorrowful', 'regretful']]
#
# # substitute the word with its synonym, pseudo-code
#
# for i, word in (input_text)
#
#   for set_word in (reserved)
#
#     for i, syn in set_word
#
#       if (syn == word)
#
#         input_text[i] = set_word[i+1]
#
# ```
#
#
#
# The happy path code does not cover error checking, but the salient point is that the library’s function follows the standard sequential coding method.
#
# On the other hand, ML is based on one of the 13 known ML algorithms, including deep learning (DL) (or artificial neural networks), Bidirectional Encoder Representations from Transformers (BERT), linear regression, random
#
# forest, Naive Bayes, and gradience boosting. The key to ML is that the system learns and not programs. DL uses the Universal Approximation theory, gradient descent, transfer learning, and hundreds of other techniques. ANNs have millions to billions of neural nodes – for example, OpenAI GPT3 has 96 layers and 175 billion nodes. The central point is that ML has no familiarity with the _print_aug_reserved() pseudocode algorithm.
#
# The following is a representation of a DL architecture for image classification. It illustrates the difference between a procedural approach and the Neural Network algorithm. This figure was created from Latex and the Overleaf cloud system. The output is as follows:
#
# > ...skip...image...
#
# Figure 6.1 – Representation of a DL model
#
# The Overleaf project and its code are from Mr. Duc Haba’s public repository, and the URL is https://www.overleaf.com/project/6369a1eaba583e7cd423171b. You can clone and hack the code to display other AI models.
#
# This chapter will cover text augmentation with ML, and in particular, the following topics:
#
# - Machine learning models
#
# - Word augmenting
#
# - Sentence augmenting
#
# - Real-world NLP datasets
#
# - Reinforcing your learning through the Python Notebook
#
# Let’s briefly describe the ML models used in the Python wrapper function code.
#
# ---
#
# 🌴 *end of excerpt from the book*

# %% [markdown]
# # GitHub Clone

# %%
# !pip install gensim==4.2.0
import gensim
# print(gensim.__version__)
# # version4.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gensim==4.2.0
#   Downloading gensim-4.2.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 31.9 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim==4.2.0) (6.3.0)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.9/dist-packages (from gensim==4.2.0) (1.10.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from gensim==4.2.0) (1.22.4)
# Installing collected packages: gensim
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.1
#     Uninstalling gensim-4.3.1:
#       Successfully uninstalled gensim-4.3.1
# Successfully installed gensim-4.2.0

# %%
# git version should be 2.17.1 or higher
# !git --version
# Out:
# git version 2.25.1

# %%
url = 'https://github.com/PacktPublishing/Data-Augmentation-with-Python'
# !git clone {url}
# Out:
# Cloning into 'Data-Augmentation-with-Python'...
# remote: Enumerating objects: 162, done.
# remote: Counting objects: 100% (140/140), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 162 (delta 73), reused 107 (delta 47), pack-reused 22
# Receiving objects: 100% (162/162), 13.24 MiB | 16.68 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %% [markdown]
# ## Fetch file from URL (Optional)
#
# - Uncommend the below 2 code cells if you want to use URL and not Git Clone

# %%
# import requests
# #
# def fetch_file(url, dst):
#   downloaded_obj = requests.get(url)
#   with open(dst, "wb") as file:
#     file.write(downloaded_obj.content)
#   return

# %%
# url = ''
# dst = 'pluto_chapter_1.py'
# fetch_file(url,dst)

# %% [markdown]
# # Run Pluto
#
# - Instantiate up Pluto, aka. "Pluto, wake up!"

# %%
# %% CARRY-OVER code install

# !pip install opendatasets --upgrade
# !pip install pyspellchecker 
# !pip install missingno
# !pip install nltk
# !pip install wordcloud
# !pip install filter-profanity
# !pip install nlpaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.2-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 34.0 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: missingno in /usr/local/lib/python3.9/dist-packages (0.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from missingno) (1.10.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.9/dist-packages (from missingno) (0.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from missingno) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from missingno) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.9/dist-packages (from seaborn->missingno) (1.5.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->missingno) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.25->seaborn->missingno) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (3.8.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nltk) (4.65.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.9/dist-packages (from nltk) (2022.10.31)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting filter-profanity
#   Downloading filter-profanity-1.0.9.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: filter-profanity
#   Building wheel for filter-profanity (setup.py) ... done
#   Created wheel for filter-profanity: filename=filter_profanity-1.0.9-py3-none-any.whl size=5219 sha256=17aeb1eb1ad7839916931c60499f6b4a1fec2f7884d86301335e1b7452de69ed
#   Stored in directory: /root/.cache/pip/wheels/48/fc/0d/0d23257e5c9bd082786e83a863e2721072170558686d55eba9
# Successfully built filter-profanity
# Installing collected packages: filter-profanity
# Successfully installed filter-profanity-1.0.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nlpaug
#   Downloading nlpaug-1.1.11-py3-none-any.whl (410 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 8.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (2.27.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (1.22.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (1.5.3)
# Requirement already satisfied: gdown>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from nlpaug) (4.6.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (4.11.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown>=4.0.0->nlpaug) (3.12.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->nlpaug) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.2.0->nlpaug) (2.8.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (1.26.15)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug) (2.4.1)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests>=2.22.0->nlpaug) (1.7.1)
# Installing collected packages: nlpaug
# Successfully installed nlpaug-1.1.11

# %%
#load and run the pluto chapter 1 Python code.
pluto_file = 'Data-Augmentation-with-Python/pluto/pluto_chapter_5.py'
# %run {pluto_file}
# Out:
# ---------------------------- : ----------------------------
#             Hello from class : <class '__main__.PacktDataAug'> Class: PacktDataAug
#                    Code name : Pluto
#                    Author is : Duc Haba
# ---------------------------- : ----------------------------
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Verify Pluto

# %%
pluto.say_sys_info()
# Out:
# ---------------------------- : ----------------------------
#                  System time : 2023/04/26 21:49
#                     Platform : linux
#      Pluto Version (Chapter) : 5.0
#              Python (3.7.10) : actual: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#             PyTorch (1.11.0) : actual: 2.0.0+cu118
#               Pandas (1.3.5) : actual: 1.5.3
#                  PIL (9.0.0) : actual: 8.4.0
#           Matplotlib (3.2.2) : actual: 3.7.1
#                    CPU count : 4
#                    CPU speed : 2.30 GHz
#                CPU max speed : 0.00 GHz
# ---------------------------- : ----------------------------

# %% [markdown]
# ## (Optional) Export to .py

# %%
pluto_chapter_6 = 'Data-Augmentation-with-Python/pluto/pluto_chapter_6.py'
# !cp {pluto_file} {pluto_chapter_6}

# %% [markdown]
# # ✋ Get Kaggle username and api key (Optional for this chapter)
#
# - Install the following libraries, and import it on the Notebook.
# - Follow by initialize Kaggle username, key and fetch methods.
# - STOP: Update your Kaggle access username or key first.

# %%
# -------------------- : --------------------
# READ ME
# Chapter 2 begin:
# Install the following libraries, and import it on the Notebook.
# Follow by initialize Kaggle username, key and fetch methods.
# STOP: Update your Kaggle access username or key first.
# -------------------- : --------------------

# !pip install opendatasets --upgrade
import opendatasets
print("\nrequired version 0.1.22 or higher: ", opendatasets.__version__)

# !pip install pyspellchecker 
import spellchecker
print("\nRequired version 0.7+", spellchecker.__version__)

# STOP: Update your Kaggle access username or key first.
pluto.remember_kaggle_access_keys("YOUR-USERNAME", "YOUR-KEY")
pluto._write_kaggle_credit()
import kaggle

@add_method(PacktDataAug)
def fetch_kaggle_comp_data(self,cname):
  #self._write_kaggle_credit()  # need to run only once.
  path = pathlib.Path(cname)
  kaggle.api.competition_download_cli(str(path))
  zipfile.ZipFile(f'{path}.zip').extractall(path)
  return

@add_method(PacktDataAug)
def fetch_kaggle_dataset(self,url,dest="kaggle"):
  #self._write_kaggle_credit()    # need to run only once.
  opendatasets.download(url,data_dir=dest)
  return
# -------------------- : --------------------
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opendatasets in /usr/local/lib/python3.9/dist-packages (0.1.22)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.9/dist-packages (from opendatasets) (1.5.13)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2022.12.7)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (1.26.15)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (8.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.9/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->kaggle->opendatasets) (3.4)
#
# required version 0.1.22 or higher:  0.1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspellchecker in /usr/local/lib/python3.9/dist-packages (0.7.2)
#
# Required version 0.7+ 0.7.2

# %% [markdown]
# # Fetch data from chapter 5

# %%
f = 'Data-Augmentation-with-Python/pluto_data'
# !ls -la {f}
# Out:
# total 9372
# drwxr-xr-x  2 root root    4096 Apr 26 21:48 .
# drwxr-xr-x 16 root root    4096 Apr 26 21:48 ..
# -rw-r--r--  1 root root  102877 Apr 26 21:48 control-d-major.mp3
# -rw-r--r--  1 root root 3404721 Apr 26 21:48 netflix_data.csv
# -rw-r--r--  1 root root 6072376 Apr 26 21:48 twitter_data.csv

# %%
f = 'Data-Augmentation-with-Python/pluto_data/netflix_data.csv'
pluto.df_netflix_data = pluto.fetch_df(f,sep='~')

# %%
f = 'Data-Augmentation-with-Python/pluto_data/twitter_data.csv'
pluto.df_twitter_data = pluto.fetch_df(f,sep='~')

# %%
pluto.print_batch_text(pluto.df_netflix_data, cols=['title','description'])
# Out:
# <style type="text/css">
# #T_9957c th {
#   font-size: 20px;
# }
# #T_9957c td {
#   font-size: 18px;
# }
# </style>
# <table id="T_9957c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9957c_level0_col0" class="col_heading level0 col0" >title</th>
#       <th id="T_9957c_level0_col1" class="col_heading level0 col1" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9957c_level0_row0" class="row_heading level0 row0" >1394</th>
#       <td id="T_9957c_row0_col0" class="data row0 col0" >Spycraft</td>
#       <td id="T_9957c_row0_col1" class="data row0 col1" >The spy game is a serious business, and throughout history, the tools and technologies developed for it have mattered as much as the spies themselves.</td>
#     </tr>
#     <tr>
#       <th id="T_9957c_level0_row1" class="row_heading level0 row1" >6788</th>
#       <td id="T_9957c_row1_col0" class="data row1 col0" >Forget Me Not</td>
#       <td id="T_9957c_row1_col1" class="data row1 col1" >Teenage Xue Ming was forced to marry the man who raped her. Years after abandoning her young sons to find a better life, can she escape the guilt?</td>
#     </tr>
#     <tr>
#       <th id="T_9957c_level0_row2" class="row_heading level0 row2" >5668</th>
#       <td id="T_9957c_row2_col0" class="data row2 col0" >Happy And</td>
#       <td id="T_9957c_row2_col1" class="data row2 col1" >This relatable relationship drama explores the reallife trials and joys of married life through the lens of 11 different wives.</td>
#     </tr>
#     <tr>
#       <th id="T_9957c_level0_row3" class="row_heading level0 row3" >566</th>
#       <td id="T_9957c_row3_col0" class="data row3 col0" >Charlie's Angels</td>
#       <td id="T_9957c_row3_col1" class="data row3 col1" >A tightknit trio of specially trained agents wield weapons  and charm  as they track down stolen software in this reboot of the classic TV series.</td>
#     </tr>
#     <tr>
#       <th id="T_9957c_level0_row4" class="row_heading level0 row4" >7048</th>
#       <td id="T_9957c_row4_col0" class="data row4 col0" >I'll See You in My Dreams</td>
#       <td id="T_9957c_row4_col1" class="data row4 col1" >After the passing of her dog, a longwidowed senior citizen is in need of companionship. Two very different possibilities present themselves.</td>
#     </tr>
#     <tr>
#       <th id="T_9957c_level0_row5" class="row_heading level0 row5" >1248</th>
#       <td id="T_9957c_row5_col0" class="data row5 col0" >Biggie: I Got a Story to Tell</td>
#       <td id="T_9957c_row5_col1" class="data row5 col1" >Featuring rare footage and indepth interviews, this documentary celebrates the life of The Notorious B.I.G. on his journey from hustler to rap king.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.draw_text_wordcloud(pluto.df_netflix_data.description, 
  xignore_words=wordcloud.STOPWORDS, 
  title='Word Cloud: Netflix Movie Review')

# %%
pluto.draw_text_wordcloud(pluto.df_twitter_data.clean_tweet, 
  xignore_words=wordcloud.STOPWORDS, 
  title='Word Cloud: Twitter Tweets')

# %% [markdown]
# ## Extened control text

# %%
# %%writefile -a {pluto_chapter_6}

pluto.version = 7.0
#
pluto.orig_text = '''It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.'''
pluto.orig_dickens_page = '''There were a king with a large jaw and a queen with a plain face, 
on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France. 
In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes, 
that things in general were settled for ever.
It was the year of Our Lord one thousand seven hundred and seventy-five. 
Spiritual revelations were conceded to England at that favoured period, 
as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday, 
of whom a prophetic private in the Life Guards had heralded the sublime appearance 
by announcing that arrangements were made for the swallowing up of London and Westminster. 
Even the Cock-lane ghost had been laid only a round dozen of years, 
after rapping out its messages, 
as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs. 
Mere messages in the earthly order of events had lately come to the English Crown and People, 
from a congress of British subjects in America: which, strange to relate, 
have proved more important to the human race than any communications yet received through any of the chickens of the Cock-lane brood.'''

pluto.orig_melville_page2 = '''Call me Ishmael. 
Some years ago—never mind how long precisely—having little or no money in my purse, 
and nothing particular to interest me on shore, 
I thought I would sail about a little and see the watery part of the world. 
It is a way I have of driving off the spleen and regulating the circulation.'''

pluto.orig_melville_page = '''Call me Ishmael. 
Some years ago—never mind how long precisely—having little or no money in my purse, 
and nothing particular to interest me on shore, 
I thought I would sail about a little and see the watery part of the world. 
It is a way I have of driving off the spleen and regulating the circulation. 
Whenever I find myself growing grim about the mouth; whenever it is a damp, 
drizzly November in my soul; 
whenever I find myself involuntarily pausing before coffin warehouses, 
and bringing up the rear of every funeral I meet; 
and especially whenever my hypos get such an upper hand of me, 
that it requires a strong moral principle to prevent me from deliberately stepping into the street, 
and methodically knocking people’s hats off—then, 
I account it high time to get to sea as soon as I can. 
This is my substitute for pistol and ball. 
With a philosophical flourish Cato throws himself upon his sword; 
I quietly take to the ship. There is nothing surprising in this. 
If they but knew it, almost all men in their degree, some time or other, 
cherish very nearly the same feelings towards the ocean with me.'''

#
pluto.orig_carroll_page = '''Alice was beginning to get very tired of sitting by her sister on the bank, 
and of having nothing to do. 
Once or twice she had peeped into the book her sister was reading, 
but it had no pictures or conversations in it. 
“and what is the use of a book,” thought Alice “without pictures or conversations?”
So she was considering in her own mind. as well as she could, 
for the hot day made her feel very sleepy and stupid. 
whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, 
when suddenly a White Rabbit with pink eyes ran close by her.
There was nothing so very remarkable in that; 
nor did Alice think it so very much out of the way to hear the Rabbit say to itself. 
“Oh dear! Oh dear! I shall be late!” 
when she thought it over afterwards, 
it occurred to her that she ought to have wondered at this, 
but at the time it all seemed quite natural; 
but when the Rabbit actually took a watch out of its waistcoat-pocket, 
and looked at it, and then hurried on, Alice started to her feet, 
for it flashed across her mind that she had never before seen a rabbit with either a waistcoat-pocket, 
or a watch to take out of it, 
and burning with curiosity, 
she ran across the field after it, 
and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.
'''
#
pluto.orig_carroll_page2 = '''Alice was beginning to get very tired of sitting by her sister on the bank, 
and of having nothing to do. 
Once or twice she had peeped into the book her sister was reading, 
but it had no pictures or conversations in it.
“and what is the use of a book,” thought Alice “without pictures or conversations?”
So she was considering in her own mind. as well as she could, 
for the hot day made her feel very sleepy and stupid. 
whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, 
when suddenly a White Rabbit with pink eyes ran close by her.'''
#
pluto.orig_self = '''Text augmentation with Machine Learning (ML) is an advanced technique. 
Ironically, Text augmentation aims to improve ML model accuracy, 
but we used a pre-trained ML model to create additional training NLP data. 
It’s a circular process. ML coding is not in this book’s scope, 
but understanding the difference between text augmentation using libraries and ML is beneficial.  
Augmentation libraries, whether for image, text, or audio, 
follow the traditional programming methodologies with structure data, loops, 
and conditional statements in the algorithm. 
For example, from Chapter 5, the pseudo-code for implementing the method _print_aug_reserved() could be as follows:'''

# %%
# %%writefile -a {pluto_chapter_6}

@add_method(PacktDataAug)
def _clean_text(self,x):
  return (re.sub('[^A-Za-z0-9 .,!?#@]+', '', str(x)))

# %%
pluto.df_netflix_data['description'] = pluto.df_netflix_data['description'].apply(pluto._clean_text)

# %% [markdown]
# # Word2Vec

# %%
# !ls -la ../model/

# %%
# %%writefile -a {pluto_chapter_6}

from nlpaug.util.file.download import DownloadUtil

#DownloadUtil.download_word2vec(dest_dir='.') # word2vec
DownloadUtil.download_glove(model_name='glove.6B', dest_dir='.') # GloVe
DownloadUtil.download_fasttext(model_name='wiki-news-300d-1M', dest_dir='.') # fasttext model

# %%
# %%writefile -a {pluto_chapter_6}

try:
  DownloadUtil.download_word2vec(dest_dir='.') # word2vec
except Exception:
  print('\nIt happen frequently that this file can not be download due to too many access.')
  print('When it failed, you can not use Word2Vec transformation/augmentation.')
  print('You could download the file: GoogleNews-vectors-negative300.bin.gz')
  print('From URL: https://drive.google.com/uc?export=download&id=0B7XkCwpI5KDYNlNUTTlSS21pQmM \n')
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=0B7XkCwpI5KDYNlNUTTlSS21pQmM
# To: /content/GoogleNews-vectors-negative300.bin.gz
# 100%|██████████| 1.65G/1.65G [00:17<00:00, 93.6MB/s]

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug
@add_method(PacktDataAug)
def print_aug_ai_word2vec(self, df, 
  col_dest="description",
  action='insert',
  model_type='word2vec',
  model_path='GoogleNews-vectors-negative300.bin',
  bsize=3, 
  aug_name='Augment',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.word.WordEmbsAug(model_type=model_type,action=action,model_path=model_path)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_ai_word2vec(pluto.df_netflix_data,
  col_dest='description',
  action='insert',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_3eb19 th {
#   font-size: 20px;
# }
# #T_3eb19 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_3eb19" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3eb19_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_3eb19_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3eb19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3eb19_row0_col0" class="data row0 col0" >It was the best COOS of times. CHESTER It was the originating worst of times. It was the age ##/###/####BaseT of wisdom. Inc. It was the age of foolishness. It was the Brenan epoch of Shaw belief. Masque It was Everglades the IHE epoch of incredulity.</td>
#       <td id="T_3eb19_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_3eb19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3eb19_row1_col0" class="data row1 col0" >A Ghulam young man falls for a heroic general McConnell and soon follows her Designated footsteps as humans defend Helghast Earth John against extraterrestrials EMKE seeking Charles a precious midfielder energy source.</td>
#       <td id="T_3eb19_row1_col1" class="data row1 col1" >A young man falls for a heroic general and soon follows her footsteps as humans defend Earth against extraterrestrials seeking a precious energy source.</td>
#     </tr>
#     <tr>
#       <th id="T_3eb19_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3eb19_row2_col0" class="data row2 col0" >With Mehrunnisa the peak of his career long behind Pinewild him, an actor Douglas clings to his past glory IHME until supplement a Kamela sudden sachs wakeup call forces him to Mattias face who www.scott hes become.</td>
#       <td id="T_3eb19_row2_col1" class="data row2 col1" >With the peak of his career long behind him, an actor clings to his past glory  until a sudden wakeup call forces him to face who hes become.</td>
#     </tr>
#     <tr>
#       <th id="T_3eb19_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3eb19_row3_col0" class="data row3 col0" >Conducting Arvind a study on the Apple psychology of Altra incarceration, a vortex Stanford professor assigns guard and acrylic prisoner roles to 24 male Çakır test subjects MobilePlanet in Rs.2 a à mock jail.</td>
#       <td id="T_3eb19_row3_col1" class="data row3 col1" >Conducting a study on the psychology of incarceration, a Stanford professor assigns guard and prisoner roles to 24 male test subjects in a mock jail.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_word2vec(pluto.df_netflix_data,
  col_dest='description',
  action='insert',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_83b41 th {
#   font-size: 20px;
# }
# #T_83b41 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_83b41" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83b41_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_83b41_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83b41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83b41_row0_col0" class="data row0 col0" >It was titanium the best Yamama of Collating times. It Agency was Indulging the worst of times. It subsets was the ========================== age of wisdom. Asik It was the age of foolishness. inhibit It was the epoch of belief. It chromium was the epoch of incredulity.</td>
#       <td id="T_83b41_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_83b41_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83b41_row1_col0" class="data row1 col0" >Dynamic reenactments Military and expert exasperate commentaries bring to life the hanged tumultuous history and power Zeddy struggles of Ablaze a london warring Ahwaz 16thcentury feudal Japan.</td>
#       <td id="T_83b41_row1_col1" class="data row1 col1" >Dynamic reenactments and expert commentaries bring to life the tumultuous history and power struggles of a warring 16thcentury feudal Japan.</td>
#     </tr>
#     <tr>
#       <th id="T_83b41_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_83b41_row2_col0" class="data row2 col0" >Frustrated FOR with the stalled investigation into motorsports her IUOE husbands Ending murder, a woman searches for the bed killer on BY her own, CarRentals.com putting herself in grave Anfac danger.</td>
#       <td id="T_83b41_row2_col1" class="data row2 col1" >Frustrated with the stalled investigation into her husbands murder, a woman searches for the killer on her own, putting herself in grave danger.</td>
#     </tr>
#     <tr>
#       <th id="T_83b41_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_83b41_row3_col0" class="data row3 col0" >Max When Wagtail her estranged mother falls into Lonel a Mussorgsky coma, a selfmade DenteMax single mom grapples with familys regret and resentment while reflecting on Malarz their strained proximal relationship.</td>
#       <td id="T_83b41_row3_col1" class="data row3 col1" >When her estranged mother falls into a coma, a selfmade single mom grapples with regret and resentment while reflecting on their strained relationship.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_word2vec(pluto.df_twitter_data,col_dest='clean_tweet',action='insert',aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_508a3 th {
#   font-size: 20px;
# }
# #T_508a3 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_508a3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_508a3_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_508a3_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_508a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_508a3_row0_col0" class="data row0 col0" >It was the multithreaded best Rep. of times. It was overlapping the worst of times. Hoffbauer It was KTX the age Lankan of wisdom. It was the age of foolishness. Slave It valves was the epoch Redknee of belief. It was Tieng the epoch of incredulity.</td>
#       <td id="T_508a3_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_508a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_508a3_row1_col0" class="data row1 col0" >each amp everyone Hei of Lew the england hooligans Aykley should Darvel have there passpo By banned EUR for 10 years amp not just to Inc. football should be to Bud anywhere!</td>
#       <td id="T_508a3_row1_col1" class="data row1 col1" >each amp everyone of the england hooligans should have there passpo banned for 10 years amp not just to football should be to anywhere!</td>
#     </tr>
#     <tr>
#       <th id="T_508a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_508a3_row2_col0" class="data row2 col0" >tumbledown tomorrow www.london.gov.uk is aquariums the day Paul of my # Denkin audition at the # rock # academy in # abstracts tilburg! ! # DJ music</td>
#       <td id="T_508a3_row2_col1" class="data row2 col1" >tomorrow is the day of my #audition at the #rock #academy in #tilburg!! #music</td>
#     </tr>
#     <tr>
#       <th id="T_508a3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_508a3_row3_col0" class="data row3 col0" >u mean? ? reveal Casino ur Bioteau marriage CRPF date?</td>
#       <td id="T_508a3_row3_col1" class="data row3 col1" >u mean?? reveal ur marriage date?</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Substitute

# %%
pluto.print_aug_ai_word2vec(pluto.df_netflix_data,
  col_dest='description',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_cb1a4 th {
#   font-size: 20px;
# }
# #T_cb1a4 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_cb1a4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb1a4_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_cb1a4_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb1a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb1a4_row0_col0" class="data row0 col0" >Either was them best of prescribed_corticosteroids. It was the craziest of times. It was the yearolds of wisdom. Or_maybe being the officer_Aslam_Gujjar of foolishness. It was the epoch_defining of belief. Certainly was the epoch of incredulity.</td>
#       <td id="T_cb1a4_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_cb1a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb1a4_row1_col0" class="data row1 col0" >Yanto submits Hagai_Ben_Artzi friends to assistance save a Christine_Benedicto Able_bodied being kidnapped by a mobster. Silly slapstick and campy gumshoe ensues.</td>
#       <td id="T_cb1a4_row1_col1" class="data row1 col1" >Yanto asks his friends to help save a girlfriend who was kidnapped by a mobster. Silly slapstick and campy crimefighting ensues.</td>
#     </tr>
#     <tr>
#       <th id="T_cb1a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cb1a4_row2_col0" class="data row2 col0" >In this competition Funniest_Moments, Snuggie_clad self_tanning_lotion artists navigate garish_costumes diffi_culties to slay_Dragons a careermaking opportunity after the beauty industry.</td>
#       <td id="T_cb1a4_row2_col1" class="data row2 col1" >In this competition show, aspiring makeup artists navigate colorful challenges to win a careermaking opportunity in the beauty industry.</td>
#     </tr>
#     <tr>
#       <th id="T_cb1a4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cb1a4_row3_col0" class="data row3 col0" >Toan unconventional increased_functionality_compactness MPSD philosophy teacher upsets a few maternal_grandparents and staff, romances others and angers genders_ethnicities his pupils, andmany demeanor_belied gay son.</td>
#       <td id="T_cb1a4_row3_col1" class="data row3 col1" >An unconventional high school philosophy teacher upsets a few parents and staff, romances others and inspires all his pupils, including his gay son.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_word2vec(pluto.df_twitter_data,
  col_dest='clean_tweet',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_5be5c th {
#   font-size: 20px;
# }
# #T_5be5c td {
#   font-size: 18px;
# }
# </style>
# <table id="T_5be5c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5be5c_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_5be5c_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5be5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5be5c_row0_col0" class="data row0 col0" >That was the best of times. The was by sloppiest of times. It was only age of wisdom. Well subsequently the age of foolishness. It was By_Christine_Fenno epoch of pessimism. It seems the epoch of incredulity.</td>
#       <td id="T_5be5c_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_5be5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5be5c_row1_col0" class="data row1 col0" >@ user @ customer @ user @ TeamViewer however irrational_illogical. # downward_sloping_channel to normalizing # hatered and # nofascist2017</td>
#       <td id="T_5be5c_row1_col1" class="data row1 col1" >@user @user @user @user not denial. #resistance to normalizing #hatred and #nofascist2017</td>
#     </tr>
#     <tr>
#       <th id="T_5be5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5be5c_row2_col0" class="data row2 col0" >our brand unique externships centre considers staing to see mutually_supportive! !! ! # norwich # Trainers_TOT</td>
#       <td id="T_5be5c_row2_col1" class="data row2 col1" >our brand new training centre is staing to come together!!!! #norwich #training</td>
#     </tr>
#     <tr>
#       <th id="T_5be5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5be5c_row3_col0" class="data row3 col0" >ricky Neither intrinsically sure if im_gonna or disgrace visit_http://www.fda.gov both or neither_aminopterin or # hungry or grumpier or bored. i just dont even SERENA_WILLIAMS_Well..</td>
#       <td id="T_5be5c_row3_col1" class="data row3 col1" >im not entirely sure if im or sad or both or neither or #hungry or tired or bored. i just dont even know..</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_carroll_page], columns=['page'])
pluto.print_aug_ai_word2vec(df_page,
  col_dest='page',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_1ac42 th {
#   font-size: 20px;
# }
# #T_1ac42 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_1ac42" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ac42_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_1ac42_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ac42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ac42_row0_col0" class="data row0 col0" >This was the best of yo_yo_dieted. It shortly_afterwards first worst of ninemsn_selects. It was AEGIS_LTD age of wisdom. Just was the age of foolishness. It was was epoch of belief. That blew_gasket the epoch of incredulity.</td>
#       <td id="T_1ac42_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_1ac42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ac42_row1_col0" class="data row1 col0" >Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do. Once or twice she had peeped into the book her sister was fluency_vocabulary, but it had no pictorials or conversations in it. “ and Laughing. is that use of a book, ” thought Alice “ without pictures or Wiretapped_conversations? ” So she was considering in her own mind. as well described she could, for the hot day made her feel very sleepy and stupid. whether the pleasure of making a daisy - chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her. Of_course was nothing so very remarkable in that; nor did Alice think it so very much out of the way to hear the Rabbit say to itself. “ Oh dear! Oh dear! I shall be late! ” when she thought it over afterwards, it occurred to her that she ought to have wondered at this, but at the time it all seemed quite natural; but when the Rabbit actually took a watch out of its waistcoat - pocket, and looked at it, and then hurried on, Alice started to her feet, for it flashed across her mind that she had never before seen a rabbit with either a waistcoat - pocket, or a watch to take out of it, and burning with revulsion, she ran across the field folllowing it, and fortunately was just in point to see it pop down a large rabbit - hole under the hedge.</td>
#       <td id="T_1ac42_row1_col1" class="data row1 col1" >Alice was beginning to get very tired of sitting by her sister on the bank,
# and of having nothing to do.
# Once or twice she had peeped into the book her sister was reading,
# but it had no pictures or conversations in it.
# “and what is the use of a book,” thought Alice “without pictures or conversations?”
# So she was considering in her own mind. as well as she could,
# for the hot day made her feel very sleepy and stupid.
# whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies,
# when suddenly a White Rabbit with pink eyes ran close by her.
# There was nothing so very remarkable in that;
# nor did Alice think it so very much out of the way to hear the Rabbit say to itself.
# “Oh dear! Oh dear! I shall be late!”
# when she thought it over afterwards,
# it occurred to her that she ought to have wondered at this,
# but at the time it all seemed quite natural;
# but when the Rabbit actually took a watch out of its waistcoat-pocket,
# and looked at it, and then hurried on, Alice started to her feet,
# for it flashed across her mind that she had never before seen a rabbit with either a waistcoat-pocket,
# or a watch to take out of it,
# and burning with curiosity,
# she ran across the field after it,
# and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.
# </td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_dickens_page], columns=['page'])
pluto.print_aug_ai_word2vec(df_page,
  col_dest='page',
  action='substitute',
  aug_name='Word2Vec-GoogleNews Word Embedding Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_d46e8 th {
#   font-size: 20px;
# }
# #T_d46e8 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_d46e8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d46e8_level0_col0" class="col_heading level0 col0" >Word2Vec-GoogleNews Word Embedding Augment</th>
#       <th id="T_d46e8_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d46e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d46e8_row0_col0" class="data row0 col0" >They was By_DAVID_SCHEPP best of times. It was one worst of times. Whether was every age of wisdom. It was the ages## of hurtfulness. It was the epoch of belief. It fell A.The Babylonian_Captivity of incredulity.</td>
#       <td id="T_d46e8_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_d46e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d46e8_row1_col0" class="data row1 col0" >There were a king with a large jaw and a queen with a plain face, on the throne of England; theres were a king with a medium_sized jaw and a queen with a fair face, on the throne of Micro_Hebdo. In both countries it was clearer than crystal to the lords of the State preserves of loaves and sportfish, that things in general were settled for ever. It was the year of Our Lord nineteen thousand seven hundred and seventy - five. Spiritual revelations were conceded to England at that favoured period, as at this. Mrs. Southcott had recently attained her five - and - twentieth blessed birthday, of whom a prophetic private Enlarge_Pic the Life Guards had heralded the sublime appearance by unveiling that arrangements were made for the swallowing up of London and Westminster. Even the Cock - lane ghost had been laid only a round dozen of years, Soon_thereafter rapping out its messages, as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs. Mere messages in the earthly order of events had Already come to the English Crown and People, from a congress of British subjects in America: which, strange to relate, hesays proved more important to the human race than any communications yet received through any of the chickens of the Cock - lane brood.</td>
#       <td id="T_d46e8_row1_col1" class="data row1 col1" >There were a king with a large jaw and a queen with a plain face,
# on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes,
# that things in general were settled for ever.
# It was the year of Our Lord one thousand seven hundred and seventy-five.
# Spiritual revelations were conceded to England at that favoured period,
# as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday,
# of whom a prophetic private in the Life Guards had heralded the sublime appearance
# by announcing that arrangements were made for the swallowing up of London and Westminster.
# Even the Cock-lane ghost had been laid only a round dozen of years,
# after rapping out its messages,
# as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
# Mere messages in the earthly order of events had lately come to the English Crown and People,
# from a congress of British subjects in America: which, strange to relate,
# have proved more important to the human race than any communications yet received through any of the chickens of the Cock-lane brood.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #BERT

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.12.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 93.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.14.1 tokenizers-0.13.3 transformers-4.28.1

# %%
# %%writefile -a {pluto_chapter_6}

import transformers
print(transformers.__version__)
# Out:
# 4.28.1

# %%
# !pip install simpletransformers>=0.61.10
import simpletransformers
#print(simpletransformers.__version__)

# %%
# !pip install nltk>=3.4.5
# !pip install gensim>=4.1.2

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug
@add_method(PacktDataAug)
def print_aug_ai_bert(self, df, 
  col_dest="description",
  action='insert',
  model_path='bert-base-uncased',
  bsize=3, 
  aug_name='Augment',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.word.ContextualWordEmbsAug(action=action,model_path=model_path)
  #self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name,is_orig_control=is_orig_control)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  action='insert',aug_name='BERT Embedding Insert Augment')
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_f5efa th {
#   font-size: 20px;
# }
# #T_f5efa td {
#   font-size: 18px;
# }
# </style>
# <table id="T_f5efa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f5efa_level0_col0" class="col_heading level0 col0" >BERT Embedding Insert Augment</th>
#       <th id="T_f5efa_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f5efa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f5efa_row0_col0" class="data row0 col0" >it himself was the best of times. it was hardly the worst of times. it was certainly the shining age reborn of wisdom. it was the age of foolishness. it was indeed the new epoch of belief. it himself was even the epoch time of incredulity.</td>
#       <td id="T_f5efa_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_f5efa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f5efa_row1_col0" class="data row1 col0" >sparks fly when a young newspaper columnist unexpectedly writes a very onesided, somewhat sexist newspaper story going about a deeply commitmentphobic bride who happily abandoned their three men at the altar.</td>
#       <td id="T_f5efa_row1_col1" class="data row1 col1" >Sparks fly when a newspaper columnist writes a onesided, sexist story about a commitmentphobic bride who abandoned three men at the altar.</td>
#     </tr>
#     <tr>
#       <th id="T_f5efa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f5efa_row2_col0" class="data row2 col0" >the small fragile and secretive family world of his two sisters and their uncle crumbles when their most charming young cousin archie arrives again with eyes toward the major family fortune.</td>
#       <td id="T_f5efa_row2_col1" class="data row2 col1" >The fragile and secretive world of two sisters and their uncle crumbles when their charming cousin arrives with eyes toward the family fortune.</td>
#     </tr>
#     <tr>
#       <th id="T_f5efa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f5efa_row3_col0" class="data row3 col0" >in 1930s paris, as an actress famous for her gory haunted death mask scenes playing at the prestigious grand guignol theater successfully contends with a very mysterious undead stalker threat and ghosts from inside her past.</td>
#       <td id="T_f5efa_row3_col1" class="data row3 col1" >In 1930s Paris, an actress famous for her gory death scenes at the Grand Guignol Theater contends with a mysterious stalker and ghosts from her past.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  action='insert',aug_name='BERT Embedding Insert Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_868fe th {
#   font-size: 20px;
# }
# #T_868fe td {
#   font-size: 18px;
# }
# </style>
# <table id="T_868fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_868fe_level0_col0" class="col_heading level0 col0" >BERT Embedding Insert Augment</th>
#       <th id="T_868fe_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_868fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_868fe_row0_col0" class="data row0 col0" >likely it was the best year of times. it was the worst of times. perhaps it was not the age age of wisdom. only it was the age of foolishness. it also was the new epoch of belief. it certainly was the epoch time of incredulity.</td>
#       <td id="T_868fe_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_868fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_868fe_row1_col0" class="data row1 col0" >@ messenger user lovely for lunchtime run session with @ twitter user in # brighton australia now things were ready to tackle in the afternoon @ user # morning worklife</td>
#       <td id="T_868fe_row1_col1" class="data row1 col1" >@user lovely lunchtime run with @user in #brighton now were ready to tackle the afternoon @user #worklife</td>
#     </tr>
#     <tr>
#       <th id="T_868fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_868fe_row2_col0" class="data row2 col0" >just paying them with just a 5 yo. # alaska</td>
#       <td id="T_868fe_row2_col1" class="data row2 col1" >paying with a 5 yo. #alaska</td>
#     </tr>
#     <tr>
#       <th id="T_868fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_868fe_row3_col0" class="data row3 col0" >star wars expansion de... new gbp 49. 33 00 just get here # book shop # planet cool # fun home # fun</td>
#       <td id="T_868fe_row3_col1" class="data row3 col1" >star wars de... gbp 49.00 get here #shop #cool #home #fun</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Substitute

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  action='substitute',aug_name='BERT Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_6f820 th {
#   font-size: 20px;
# }
# #T_6f820 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_6f820" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f820_level0_col0" class="col_heading level0 col0" >BERT Embedding Substitute Augment</th>
#       <th id="T_6f820_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f820_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f820_row0_col0" class="data row0 col0" >tonight was this darkest of times. it was the worst of times. today was the age of wisdom. it was the age of foolishness. that was a epoch of death. it began a epoch of justice.</td>
#       <td id="T_6f820_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_6f820_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6f820_row1_col0" class="data row1 col0" >in the underbelly of new delhi neighborhood, a teenager searching for her missing lover filled with drugs, death for the tape pointing to the demons.</td>
#       <td id="T_6f820_row1_col1" class="data row1 col1" >In the underbelly of a Delhi neighborhood, a womans search for her missing lover collides with drugs, death and a coach grappling with his demons.</td>
#     </tr>
#     <tr>
#       <th id="T_6f820_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6f820_row2_col0" class="data row2 col0" >running through 10 discs, this compelling story follows the dna exoneree as, while exposing international corruption, finds a suspect in every grisly new crime.</td>
#       <td id="T_6f820_row2_col1" class="data row2 col1" >Filmed over 10 years, this reallife thriller follows a DNA exoneree who, while exposing police corruption, becomes a suspect in a grisly new crime.</td>
#     </tr>
#     <tr>
#       <th id="T_6f820_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6f820_row3_col0" class="data row3 col0" >that renegade hero the kid and his big pink cadillac join a small dark organization while on a assignment to find a missing prince.</td>
#       <td id="T_6f820_row3_col1" class="data row3 col1" >Immortal renegade Philly the Kid and his transforming pink Cadillac join a relentlessly upbeat friendship droid on her quest to find a missing prince.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  action='substitute',aug_name='BERT Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_51e44 th {
#   font-size: 20px;
# }
# #T_51e44 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_51e44" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_51e44_level0_col0" class="col_heading level0 col0" >BERT Embedding Substitute Augment</th>
#       <th id="T_51e44_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_51e44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_51e44_row0_col0" class="data row0 col0" >it seemed the best of times. it was another worst is times. earth had the age of wisdom. it was the age of foolishness. it presented the epoch to beauty. she found the epoch of incredulity.</td>
#       <td id="T_51e44_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_51e44_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_51e44_row1_col0" class="data row1 col0" >@ twitter profile facebook... weve more enemies to friyay # friyay # facebook # twitter # facebook # project</td>
#       <td id="T_51e44_row1_col1" class="data row1 col1" >@user smile everyone ... weve made it to friyay #friyay #friday #smile #epcot #ita</td>
#     </tr>
#     <tr>
#       <th id="T_51e44_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_51e44_row2_col0" class="data row2 col0" >am so glad 2 be off # 9 @ bain</td>
#       <td id="T_51e44_row2_col1" class="data row2 col1" >felling so glad to be awake #breakfastbythetreehouse @ quezon</td>
#     </tr>
#     <tr>
#       <th id="T_51e44_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_51e44_row3_col0" class="data row3 col0" >the end was first grade. # x</td>
#       <td id="T_51e44_row3_col1" class="data row3 col1" >the end of 10 grade. #sad</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_dickens_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  action='substitute',
  aug_name='BERT Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_503eb th {
#   font-size: 20px;
# }
# #T_503eb td {
#   font-size: 18px;
# }
# </style>
# <table id="T_503eb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_503eb_level0_col0" class="col_heading level0 col0" >BERT Embedding Substitute Augment</th>
#       <th id="T_503eb_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_503eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_503eb_row0_col0" class="data row0 col0" >it was a best of circumstances. everything was the worst into times. it was the age against wisdom. it was the age of belief. it was the epoch for belief. yet also the epoch against incredulity.</td>
#       <td id="T_503eb_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_503eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_503eb_row1_col0" class="data row1 col0" >there were a king with a large jaw and a queen with a plain face, on the throne of england ; there were a king had a large jaw and a queen with a fair jaw, on the throne of france. in both countries it was clearer than crystal to the lords of the state preserves of loaves and fishes, that disputes in general were settled for ever. it was the year of our lord one thousand seven hundred and seventy - two. spiritual revelations were conceded to england at that favoured period, as at this. mrs. southcott had evidently attained her twentieth - and - twentieth blessed birthday, in whom a prophetic private in the life guards had heralded the sublime appearance by announcing that arrangements were made for the bombing up of london and westminster. even the cock - lane ghost had been laid only a round dozen of years, after rapping out its messages, as the spirits of this very year last past ( supernaturally deficient in originality ) rapped out theirs. mere messages in the earthly order of events had lately come to the english crown and people, from a congress of british subjects in america : which, strange to relate, have proved more important to the human person than any communications yet received to any of the chickens of the cock - lane brood.</td>
#       <td id="T_503eb_row1_col1" class="data row1 col1" >There were a king with a large jaw and a queen with a plain face,
# on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes,
# that things in general were settled for ever.
# It was the year of Our Lord one thousand seven hundred and seventy-five.
# Spiritual revelations were conceded to England at that favoured period,
# as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday,
# of whom a prophetic private in the Life Guards had heralded the sublime appearance
# by announcing that arrangements were made for the swallowing up of London and Westminster.
# Even the Cock-lane ghost had been laid only a round dozen of years,
# after rapping out its messages,
# as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
# Mere messages in the earthly order of events had lately come to the English Crown and People,
# from a congress of British subjects in America: which, strange to relate,
# have proved more important to the human race than any communications yet received through any of the chickens of the Cock-lane brood.</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_melville_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  action='substitute',
  aug_name='BERT Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_580f8 th {
#   font-size: 20px;
# }
# #T_580f8 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_580f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_580f8_level0_col0" class="col_heading level0 col0" >BERT Embedding Substitute Augment</th>
#       <th id="T_580f8_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_580f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_580f8_row0_col0" class="data row0 col0" >it was the beginning of time. it was the worst over times. heaven was the age before wisdom. it was the age of foolishness. it was the answer to fate. it was the epoch from immortality.</td>
#       <td id="T_580f8_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_580f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_580f8_row1_col0" class="data row1 col0" >call me ishmael. some years ago — never mind how long precisely — has little or no money in their purse, and nothing particular to interest me on shore, i thought i would sail about a little and see the watery ends of the world. it is a way i have of driving off the spleen and regulating the circulation. whenever me find myself growing grim about the mouth ; whenever it is a damp, cold november in my soul ; whenever i find myself involuntarily pausing before coffin warehouses, and bringing up the rear of every funeral i meet ; and especially whenever my hypos get into an upper hand of me, that it requires a strong moral principle to prevent me from deliberately stepping into the street, and methodically knocking people rather s hats off — then, i account it for time to get to sea as soon as i can. this is my substitute for pistol and ball. with a philosophical flourish cato throws himself upon his sword ; i quietly take to the ship. there is nothing surprising on this. if they but knew it, almost all men in their degree, some time or other, cherish very nearly the same feelings towards the woman with me.</td>
#       <td id="T_580f8_row1_col1" class="data row1 col1" >Call me Ishmael.
# Some years ago—never mind how long precisely—having little or no money in my purse,
# and nothing particular to interest me on shore,
# I thought I would sail about a little and see the watery part of the world.
# It is a way I have of driving off the spleen and regulating the circulation.
# Whenever I find myself growing grim about the mouth; whenever it is a damp,
# drizzly November in my soul;
# whenever I find myself involuntarily pausing before coffin warehouses,
# and bringing up the rear of every funeral I meet;
# and especially whenever my hypos get such an upper hand of me,
# that it requires a strong moral principle to prevent me from deliberately stepping into the street,
# and methodically knocking people’s hats off—then,
# I account it high time to get to sea as soon as I can.
# This is my substitute for pistol and ball.
# With a philosophical flourish Cato throws himself upon his sword;
# I quietly take to the ship. There is nothing surprising in this.
# If they but knew it, almost all men in their degree, some time or other,
# cherish very nearly the same feelings towards the ocean with me.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # RoBERTa

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  model_path='roberta-base',
  action='insert',aug_name='Roberta Embedding Insert Augment')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/481 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/501M [00:00<?, ?B/s]
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_cd2a7 th {
#   font-size: 20px;
# }
# #T_cd2a7 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_cd2a7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd2a7_level0_col0" class="col_heading level0 col0" >Roberta Embedding Insert Augment</th>
#       <th id="T_cd2a7_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd2a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd2a7_row0_col0" class="data row0 col0" >It was rarely the best epoch of times. It was the worst of not times. It never was merely the age of misplaced wisdom. – It was the glorious age of foolishness. It was the epoch of belief. It moreover was the epoch ful of incredulity.</td>
#       <td id="T_cd2a7_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_cd2a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd2a7_row1_col0" class="data row1 col0" >As Bright Fields preps for its Mistletoe Costume Ball, even a broken glass ornament leads little Zoe Beth to assume a disturbing family dirty secret, while Gaby finds firmly herself at the mercy of new boss Madame Mia.</td>
#       <td id="T_cd2a7_row1_col1" class="data row1 col1" >As Bright Fields preps for its Mistletoe Ball, a broken ornament leads Zoe to a family secret, while Gaby finds herself at the mercy of new boss Mia.</td>
#     </tr>
#     <tr>
#       <th id="T_cd2a7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd2a7_row2_col0" class="data row2 col0" >In his standup poetry set, dynamic Argentine comic Lucas Lauriente animatedly rattles blasts off reflections on several different tech generations … and essentially begs kids everywhere to really stop saying goals.</td>
#       <td id="T_cd2a7_row2_col1" class="data row2 col1" >In his standup set, Argentine comic Lucas Lauriente animatedly rattles off reflections on different generations and begs kids to stop saying goals.</td>
#     </tr>
#     <tr>
#       <th id="T_cd2a7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd2a7_row3_col0" class="data row3 col0" >In of the grim Alaskan Washington winter, a naturalist hunts seals for wolves blamed for twice killing a popular local Indian boy, but he soon discovers finds instead himself swept along into a truly chilling mystery.</td>
#       <td id="T_cd2a7_row3_col1" class="data row3 col1" >In the grim Alaskan winter, a naturalist hunts for wolves blamed for killing a local boy, but he soon finds himself swept into a chilling mystery.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  model_path='roberta-base',
  action='insert',aug_name='Roberta Embedding Insert Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_dd0f5 th {
#   font-size: 20px;
# }
# #T_dd0f5 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_dd0f5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd0f5_level0_col0" class="col_heading level0 col0" >Roberta Embedding Insert Augment</th>
#       <th id="T_dd0f5_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd0f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd0f5_row0_col0" class="data row0 col0" >It was certainly the best of times. It was the worst of times. It truly was the ancient age dead of wisdom. It was the ancient age of foolishness. […] It clearly was the epoch of naive belief. • It certainly was the epoch of incredulity.</td>
#       <td id="T_dd0f5_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd0f5_row1_col0" class="data row1 col0" >@user my cats are actually one of maybe the 10 greatest fucking things imaginable ever! Because they make me oh so very happy. Stress #depression #cats #anxiety # #mentalhealth #meow</td>
#       <td id="T_dd0f5_row1_col1" class="data row1 col1" >@user my cats are one of the greatest things ever! they make me so happy. #depression #cats #anxiety #mentalhealth #meow</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd0f5_row2_col0" class="data row2 col0" >#quote #verytrue (# #fact # #urduquote # @ a good journey</td>
#       <td id="T_dd0f5_row2_col1" class="data row2 col1" >#quote #verytrue #fact #urduquote @ good journey</td>
#     </tr>
#     <tr>
#       <th id="T_dd0f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd0f5_row3_col0" class="data row3 col0" >happy Ramadan fasting,happy fasting saturday, happy Ramadan weekend happy bank holiday,alaways # be happy with everyday tomorrow #days13 #ramadan #morn #pagi</td>
#       <td id="T_dd0f5_row3_col1" class="data row3 col1" >happy fasting,happy saturday, happy weekend happy holiday,alaways be happy everyday #days13 #ramadan #morn #pagi</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Substitute

# %%
pluto.print_aug_ai_bert(pluto.df_netflix_data,col_dest='description',
  model_path='roberta-base',
  action='substitute',aug_name='Roberta Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_b6787 th {
#   font-size: 20px;
# }
# #T_b6787 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_b6787" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6787_level0_col0" class="col_heading level0 col0" >Roberta Embedding Substitute Augment</th>
#       <th id="T_b6787_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6787_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6787_row0_col0" class="data row0 col0" >It was the better of times. It was the best of decades. It was our age beyond belief. It was the age of trust. It was the season of belief. It became the spectacle of incredulity.</td>
#       <td id="T_b6787_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_b6787_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6787_row1_col0" class="data row1 col0" >Back near her childhood home to help and sister die for their comatose parents, Alicia makes face by strange force in their subconscious that now threatens her child.</td>
#       <td id="T_b6787_row1_col1" class="data row1 col1" >Back in her childhood home to help her sister care for their comatose mother, Alicia must face a dark force from her past that now threatens her child.</td>
#     </tr>
#     <tr>
#       <th id="T_b6787_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6787_row2_col0" class="data row2 col0" >A promising bonding opportunity has a dark & decidedly dangerous twist as a father her daughter try yet another escape room in a small cabin.</td>
#       <td id="T_b6787_row2_col1" class="data row2 col1" >A lighthearted bonding opportunity takes a dark and decidedly dangerous turn when a father and daughter try out an escape room in a small town.</td>
#     </tr>
#     <tr>
#       <th id="T_b6787_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6787_row3_col0" class="data row3 col0" >Kevin Williamson cracks up laughs and brick oven bread from back balcony of his home, and comments on male group sex, sex after 40 amid struggles with diabetes.</td>
#       <td id="T_b6787_row3_col1" class="data row3 col1" >Kevin Hart serves up laughs and brick oven pizza from the comfort of his home, and dishes on male group chats, sex after 40 and life with COVID19.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_bert(pluto.df_twitter_data,col_dest='clean_tweet',
  model_path='roberta-base',
  action='substitute',aug_name='Roberta Embedding Substitute Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_595f6 th {
#   font-size: 20px;
# }
# #T_595f6 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_595f6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_595f6_level0_col0" class="col_heading level0 col0" >Roberta Embedding Substitute Augment</th>
#       <th id="T_595f6_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_595f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_595f6_row0_col0" class="data row0 col0" >It seemed the greatest unto times. It was this worst among times. That was the peak of wisdom. It was the age of foolishness. This was an era of belief. It was the epoch of incredulity.</td>
#       <td id="T_595f6_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_595f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_595f6_row1_col0" class="data row1 col0" >@user #eurgbp coin for 75.7950 cents -- uk c - #silver coin price</td>
#       <td id="T_595f6_row1_col1" class="data row1 col1" >@user #eurgbp recedes to 0.7950 ahead of uk cpi #blog #silver #gold #forex</td>
#     </tr>
#     <tr>
#       <th id="T_595f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_595f6_row2_col0" class="data row2 col0" >@user That feel soooo mad</td>
#       <td id="T_595f6_row2_col1" class="data row2 col1" >@user i am soooo @user</td>
#     </tr>
#     <tr>
#       <th id="T_595f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_595f6_row3_col0" class="data row3 col0" >brought - up - our use in #comics & # / #manga #toons</td>
#       <td id="T_595f6_row3_col1" class="data row3 col1" >brought me reds in to work... #caoons #comics #as #markers #anime #manga #toons</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_dickens_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  model_path='roberta-base',
  action='substitute',
  aug_name='Roberta Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_b6829 th {
#   font-size: 20px;
# }
# #T_b6829 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_b6829" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6829_level0_col0" class="col_heading level0 col0" >Roberta Embedding Substitute Augment</th>
#       <th id="T_b6829_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6829_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6829_row0_col0" class="data row0 col0" >It was the night of nations. It was the dark of times. It was the age with evil. It was also age of foolishness. It was the idea of prosperity. Today was the epoch of evil.</td>
#       <td id="T_b6829_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_b6829_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6829_row1_col0" class="data row1 col0" >There were a king with a large jaw and a queen with a plain face,
# on his throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal from most lords of the State preserves of loaves and fishes,
# that things in general were bound for life.
# It was the age of Our Lord one thousand seven hundred and seventy-five.
# Spiritual revelations were conceded to England at that favoured period,
# as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday,
# of whom a prophetic private in the Life Guards had heralded the sublime appearance
# by announcing that proceedings were made for his swallowing up of London as Westminster.
# Even the Cock-lane ghost had been laid only a round dozen of years,
# after rapping out its messages,
# as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
# Mere messages in the earthly order of events had lately come to the English Crown and People,
# from a congress of British subjects in America: which, strange to relate,
# have proved more important to the human race than any communications yet received through any of our chickens of the Cock-lane brood.</td>
#       <td id="T_b6829_row1_col1" class="data row1 col1" >There were a king with a large jaw and a queen with a plain face,
# on the throne of England; there were a king with a large jaw and a queen with a fair face, on the throne of France.
# In both countries it was clearer than crystal to the lords of the State preserves of loaves and fishes,
# that things in general were settled for ever.
# It was the year of Our Lord one thousand seven hundred and seventy-five.
# Spiritual revelations were conceded to England at that favoured period,
# as at this. Mrs. Southcott had recently attained her five-and-twentieth blessed birthday,
# of whom a prophetic private in the Life Guards had heralded the sublime appearance
# by announcing that arrangements were made for the swallowing up of London and Westminster.
# Even the Cock-lane ghost had been laid only a round dozen of years,
# after rapping out its messages,
# as the spirits of this very year last past (supernaturally deficient in originality) rapped out theirs.
# Mere messages in the earthly order of events had lately come to the English Crown and People,
# from a congress of British subjects in America: which, strange to relate,
# have proved more important to the human race than any communications yet received through any of the chickens of the Cock-lane brood.</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_page = pandas.DataFrame([pluto.orig_melville_page], columns=['page'])
pluto.print_aug_ai_bert(df_page,
  col_dest='page',
  model_path='roberta-base',
  action='substitute',
  aug_name='Roberta Embedding Substitute Augment',
  bsize=1,
  is_orig_control=False)
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_547da th {
#   font-size: 20px;
# }
# #T_547da td {
#   font-size: 18px;
# }
# </style>
# <table id="T_547da" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_547da_level0_col0" class="col_heading level0 col0" >Roberta Embedding Substitute Augment</th>
#       <th id="T_547da_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_547da_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_547da_row0_col0" class="data row0 col0" >It was the darkest of times. It is the worse of them. It moved from age of wisdom. It was the age of foolishness. It was the epoch when belief. First and then epoch of incredulity.</td>
#       <td id="T_547da_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_547da_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_547da_row1_col0" class="data row1 col0" >Call me Ishmael.
# Some years ago—never mind how long precisely—having little or no money in my purse,
# and nothing particular to interest me on shore,
# I thought I would sail about a little and see the watery ends of the world.
# It is a way I have of driving off the spleen and regulating the circulation.
# Whenever I find myself growing grim about the mouth; whenever it is a damp,
# drizzly November in my soul;
# whenever I find myself involuntarily reaching before coffin warehouses,
# and bringing up the rear of every funeral I meet;
# and especially whenever my hypos get such an upper hand of me,
# that it requires a strong moral principle must refrain me from deliberately stepping into such street,
# and thereby knocking my hats off—then,
# I account of high time to get to sea as soon as I can.
# This is my substitute for pistol and ball.
# With a philosophical flourish Cato throws himself upon his sword;
# I quietly take to the ship. There is nothing surprising in this.
# If they but knew it, almost all men in their life, some time or other,
# cherish very nearly the same feelings towards the ocean with contempt.</td>
#       <td id="T_547da_row1_col1" class="data row1 col1" >Call me Ishmael.
# Some years ago—never mind how long precisely—having little or no money in my purse,
# and nothing particular to interest me on shore,
# I thought I would sail about a little and see the watery part of the world.
# It is a way I have of driving off the spleen and regulating the circulation.
# Whenever I find myself growing grim about the mouth; whenever it is a damp,
# drizzly November in my soul;
# whenever I find myself involuntarily pausing before coffin warehouses,
# and bringing up the rear of every funeral I meet;
# and especially whenever my hypos get such an upper hand of me,
# that it requires a strong moral principle to prevent me from deliberately stepping into the street,
# and methodically knocking people’s hats off—then,
# I account it high time to get to sea as soon as I can.
# This is my substitute for pistol and ball.
# With a philosophical flourish Cato throws himself upon his sword;
# I quietly take to the ship. There is nothing surprising in this.
# If they but knew it, almost all men in their degree, some time or other,
# cherish very nearly the same feelings towards the ocean with me.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Back Translation

# %%
# !pip install sacremoses
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from sacremoses) (2022.10.31)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from sacremoses) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from sacremoses) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sacremoses) (4.65.0)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895259 sha256=618f10542a5d7333884325ee92dee4664328b70bcbb5432751399dffc5da47e8
#   Stored in directory: /root/.cache/pip/wheels/12/1c/3d/46cf06718d63a32ff798a89594b61e7f345ab6b36d909ce033
# Successfully built sacremoses
# Installing collected packages: sacremoses
# Successfully installed sacremoses-0.0.53

# %%
# %%writefile -a {pluto_chapter_6}

@add_method(PacktDataAug)
def print_aug_ai_back_translation(self, df, col_dest="description",
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  bsize=3, aug_name='Augment',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.word.BackTranslationAug(from_model_name=from_model_name,
    to_model_name=to_model_name)
  self._print_aug_batch(df, aug_func,col_dest=col_dest,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.print_aug_ai_back_translation(pluto.df_netflix_data,col_dest='description',
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  aug_name='FaceBook Back Translation: English <-> German Augment')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/235 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/260 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading (…)/main/vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading (…)/main/vocab-src.json:   0%|          | 0.00/849k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_6a18d th {
#   font-size: 20px;
# }
# #T_6a18d td {
#   font-size: 18px;
# }
# </style>
# <table id="T_6a18d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a18d_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> German Augment</th>
#       <th id="T_6a18d_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a18d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a18d_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of folly. It was the age of faith. It was the age of unbelief.</td>
#       <td id="T_6a18d_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_6a18d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a18d_row1_col0" class="data row1 col0" >Mr. Peabody and Sherman host a flashy latenight comedy show from a swanky penthouse, with contemporary characters and a live audience.</td>
#       <td id="T_6a18d_row1_col1" class="data row1 col1" >Mr. Peabody and Sherman host a zany latenight comedy show from a swanky penthouse, with timetraveling historical figures and a live audience.</td>
#     </tr>
#     <tr>
#       <th id="T_6a18d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a18d_row2_col0" class="data row2 col0" >A teenager forced from a violent family home to a brutal detention center learns to navigate a harsh new reality and forge unlikely alliances in order to survive.</td>
#       <td id="T_6a18d_row2_col1" class="data row2 col1" >Thrust from a violent home into a brutal custody center, a teenager learns to navigate a tough new reality and forge unlikely alliances to survive.</td>
#     </tr>
#     <tr>
#       <th id="T_6a18d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6a18d_row3_col0" class="data row3 col0" >Comedian Daniel Sloss is willing to find the funny in some very dark subjects, from the deeply personal to the truly irreverent.</td>
#       <td id="T_6a18d_row3_col1" class="data row3 col1" >Comedian Daniel Sloss is ready to find the funny in some very dark topics, from the deeply personal to the truly irreverent.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# https://huggingface.co/models

# %%
pluto.print_aug_ai_back_translation(pluto.df_twitter_data,col_dest='clean_tweet',
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  aug_name='FaceBook Back Translation: English <-> German Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_48ba5 th {
#   font-size: 20px;
# }
# #T_48ba5 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_48ba5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48ba5_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> German Augment</th>
#       <th id="T_48ba5_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48ba5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48ba5_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of folly. It was the age of faith. It was the age of unbelief.</td>
#       <td id="T_48ba5_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_48ba5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48ba5_row1_col0" class="data row1 col0" >Let my lover stop being angry with me, visit us.. # lovers # friend # astrologer # love</td>
#       <td id="T_48ba5_row1_col1" class="data row1 col1" >have my lover stop being angry at me visit us..gtgtgt #lover #friend #astrologer #love</td>
#     </tr>
#     <tr>
#       <th id="T_48ba5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48ba5_row2_col0" class="data row2 col0" >The hardest thing we have had to deal with lately has always been surpassing itself. # Hardening # Resolutions # Resolutions # Resolutions</td>
#       <td id="T_48ba5_row2_col1" class="data row2 col1" >hardest thing ive had to deal with just keeps outdoing its self lately #hardtimes #breakups #breakingup #chinup</td>
#     </tr>
#     <tr>
#       <th id="T_48ba5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48ba5_row3_col0" class="data row3 col0" ># lightroom bull up you're going to dominate your bull and you're going to direct it whatever you want.</td>
#       <td id="T_48ba5_row3_col1" class="data row3 col1" >#lightroom bull up you will dominate your bull and you will direct it whatever you want it to do. when yo</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_back_translation(pluto.df_netflix_data,col_dest='description',
  from_model_name='facebook/wmt19-en-de', 
  to_model_name='facebook/wmt19-de-en',
  aug_name='FaceBook Back Translation: English <-> German Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_31b9b th {
#   font-size: 20px;
# }
# #T_31b9b td {
#   font-size: 18px;
# }
# </style>
# <table id="T_31b9b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_31b9b_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> German Augment</th>
#       <th id="T_31b9b_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31b9b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_31b9b_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of folly. It was the age of faith. It was the age of unbelief.</td>
#       <td id="T_31b9b_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_31b9b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_31b9b_row1_col0" class="data row1 col0" >Ronny Chieng The Daily Show, Crazy Rich Asians is the focus of this standup special and riffs on modern American life and more.</td>
#       <td id="T_31b9b_row1_col1" class="data row1 col1" >Ronny Chieng The Daily Show, Crazy Rich Asians takes center stage in this standup special and riffs on modern American life and more.</td>
#     </tr>
#     <tr>
#       <th id="T_31b9b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_31b9b_row2_col0" class="data row2 col0" >The naughty and bored daughter makes a deal with her father. If she can make a good person evil, she can bury hell and stay on earth.</td>
#       <td id="T_31b9b_row2_col1" class="data row2 col1" >The devils sassy and bored daughter makes a deal with her dad If she can turn a good person evil, she gets to ditch hell and stay on Earth.</td>
#     </tr>
#     <tr>
#       <th id="T_31b9b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_31b9b_row3_col0" class="data row3 col0" >Swedish comedian David Batra gets personal when he playfully describes the merits and pitfalls of marrying a recently resigned politician.</td>
#       <td id="T_31b9b_row3_col1" class="data row3 col1" >Swedish comedian David Batra gets personal as he playfully details the perks and pitfalls of being married to a recently resigned political leader.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Russian

# %%
pluto.print_aug_ai_back_translation(pluto.df_netflix_data,col_dest='description',
  from_model_name='facebook/wmt19-en-ru', 
  to_model_name='facebook/wmt19-ru-en',
  aug_name='FaceBook Back Translation: English <-> Russian Augment')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/827 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.16G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/260 [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading (…)/main/vocab-src.json:   0%|          | 0.00/639k [00:00<?, ?B/s]
# Downloading (…)/main/vocab-tgt.json:   0%|          | 0.00/776k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/315k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading (…)/main/vocab-src.json:   0%|          | 0.00/776k [00:00<?, ?B/s]
# Downloading (…)/main/vocab-tgt.json:   0%|          | 0.00/639k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/396k [00:00<?, ?B/s]
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_497c5 th {
#   font-size: 20px;
# }
# #T_497c5 td {
#   font-size: 18px;
# }
# </style>
# <table id="T_497c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_497c5_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> Russian Augment</th>
#       <th id="T_497c5_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_497c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_497c5_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of stupidity. It was the age of faith. It was the age of mistrust.</td>
#       <td id="T_497c5_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_497c5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_497c5_row1_col0" class="data row1 col0" >This mini-series about Rita follows teacher Hjardis as she plans a school play about bullying involving a group of socially awkward students.</td>
#       <td id="T_497c5_row1_col1" class="data row1 col1" >This miniseries spinoff of Rita follows teacher Hjrdis as she plans a school play on bullying featuring a cast of socially awkward students.</td>
#     </tr>
#     <tr>
#       <th id="T_497c5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_497c5_row2_col0" class="data row2 col0" >On the streets of Senegal, a youth movement is rising against a regime seeking to seize power in this chronicle of the tumultuous 2012 election.</td>
#       <td id="T_497c5_row2_col1" class="data row2 col1" >In the streets of Senegal, a youth movement rises up against a regime bent on retaining power in this chronicle of the nations stormy 2012 elections.</td>
#     </tr>
#     <tr>
#       <th id="T_497c5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_497c5_row3_col0" class="data row3 col0" >At stake is a high school party, and two teenage yoga fanatics recruit a man to help them fight the army of monsters created by the Nazis.</td>
#       <td id="T_497c5_row3_col1" class="data row3 col1" >With an allimportant high school party at stake, two teen yoga fanatics enlist a man hunter to help fight an army of monsters created by Nazis.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_back_translation(pluto.df_twitter_data,col_dest='clean_tweet',
  from_model_name='facebook/wmt19-en-ru', 
  to_model_name='facebook/wmt19-ru-en',
  aug_name='FaceBook Back Translation: English <-> Russian Augment')
# Out:
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# /content/Data-Augmentation-with-Python/pluto/pluto_chapter_5.py:348: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_da59e th {
#   font-size: 20px;
# }
# #T_da59e td {
#   font-size: 18px;
# }
# </style>
# <table id="T_da59e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da59e_level0_col0" class="col_heading level0 col0" >FaceBook Back Translation: English <-> Russian Augment</th>
#       <th id="T_da59e_level0_col1" class="col_heading level0 col1" >Original</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da59e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da59e_row0_col0" class="data row0 col0" >It was the best time. It was the worst time. It was the age of wisdom. It was the age of stupidity. It was the age of faith. It was the age of mistrust.</td>
#       <td id="T_da59e_row0_col1" class="data row0 col1" >It was the best of times. It was the worst of times. It was the age of wisdom. It was the age of foolishness. It was the epoch of belief. It was the epoch of incredulity.</td>
#     </tr>
#     <tr>
#       <th id="T_da59e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da59e_row1_col0" class="data row1 col0" >Do you still have a launch date?</td>
#       <td id="T_da59e_row1_col1" class="data row1 col1" >exciting do you have a launch date yet?</td>
#     </tr>
#     <tr>
#       <th id="T_da59e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da59e_row2_col0" class="data row2 col0" ># movieshit bull up you will dominate your bull and you will direct it whatever you want it to do. when yo</td>
#       <td id="T_da59e_row2_col1" class="data row2 col1" >#movieshit bull up you will dominate your bull and you will direct it whatever you want it to do. when yo</td>
#     </tr>
#     <tr>
#       <th id="T_da59e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da59e_row3_col0" class="data row3 col0" >so after my exam this morning ive had a lovely day with philip and then great night with emma and kass</td>
#       <td id="T_da59e_row3_col1" class="data row3 col1" >so after my exam this morning ive had a lovely day with philip and then great night with emma and kass</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # T5-Base

# %%
# %%writefile -a {pluto_chapter_6}

@add_method(PacktDataAug)
def _fetch_larger_font(self):
  heading_properties = [('font-size', '20px')]
  cell_properties = [('font-size', '18px'), ('text-align', 'left')]
  dfstyle = [dict(selector="th", props=heading_properties),
    dict(selector="td", props=cell_properties)]
  return dfstyle

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug
import nlpaug.augmenter
@add_method(PacktDataAug)
def _print_aug_ai(self, orig, aug_func, 
  bsize=2, aug_name='Augmented',is_larger_font=True):
  aug = aug_func.augment(orig)
  data = [[aug[0]]]
  df_aug = pandas.DataFrame(data, columns=[aug_name])
  #
  if (bsize > 1):
    for i in range(bsize-1):
      aug = aug_func.augment(orig)
      data = [[aug[0]]]
      t = pandas.DataFrame(data, columns=[aug_name])
      df_aug = df_aug.append(t, ignore_index=True)
  #
  with pandas.option_context("display.max_colwidth", None):
    if (is_larger_font):
      # df_aug.style.set_properties(**{'text-align': 'left'})
      # display(df_aug.style.set_properties(**{'text-align': 'left'}))
      display(df_aug.style.set_table_styles(self._fetch_larger_font()))
    else:
      display(df_aug)
  return df_aug
#
@add_method(PacktDataAug)
def print_aug_ai_t5(self, orig, 
  bsize=2, 
  aug_name='T5_summary',
  is_orig_control=True):
  aug_func = nlpaug.augmenter.sentence.AbstSummAug(model_path='t5-base')
  df = self._print_aug_ai(orig, aug_func,bsize=bsize, aug_name=aug_name)
  return df

# %%
pluto.df_t5_carroll = pluto.print_aug_ai_t5(pluto.orig_carroll_page, bsize=1)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/models/t5/tokenization_t5_fast.py:155: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# <style type="text/css">
# #T_4eee4 th {
#   font-size: 20px;
# }
# #T_4eee4 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_4eee4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4eee4_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4eee4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4eee4_row0_col0" class="data row0 col0" >a white rabbit with pink eyes ran close by. the rabbit took a watch out of its waistcoat-pocket, and then hurried on. she ran across the field after it, and was just in time to see it pop down a rabbit-hole.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_carroll = pluto.print_aug_ai_t5(pluto.orig_carroll_page2, bsize=1)
# Out:
# <style type="text/css">
# #T_3ace0 th {
#   font-size: 20px;
# }
# #T_3ace0 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_3ace0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ace0_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ace0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ace0_row0_col0" class="data row0 col0" >white rabbit with pink eyes runs close by a daisy-chain maker. the daisies are made from a variety of flowers.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_melville = pluto.print_aug_ai_t5(pluto.orig_melville_page, bsize=1)
# Out:
# <style type="text/css">
# #T_50c8d th {
#   font-size: 20px;
# }
# #T_50c8d td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_50c8d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50c8d_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50c8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50c8d_row0_col0" class="data row0 col0" >Ishmael is a sailor who has a way of driving off the spleen and regulating the circulation. he says it is his substitute for pistol and ball to get to sea as soon as he can. almost all men in their degree, some time or other, cherish very nearly the same feelings.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_dickens = pluto.print_aug_ai_t5(pluto.orig_dickens_page, bsize=1)
# Out:
# <style type="text/css">
# #T_42105 th {
#   font-size: 20px;
# }
# #T_42105 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_42105" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42105_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42105_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_42105_row0_col0" class="data row0 col0" >david rothkopf: spiritual revelations were conceded to England at favoured time. he says even the Cock-lane ghost had been laid only a round dozen of years. the spirits of this very year last past rapped out theirs, he writes.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.df_t5_self = pluto.print_aug_ai_t5(pluto.orig_self, bsize=1)
# Out:
# <style type="text/css">
# #T_bdf83 th {
#   font-size: 20px;
# }
# #T_bdf83 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_bdf83" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdf83_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdf83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdf83_row0_col0" class="data row0 col0" >text augmentation with machine learning (ML) is an advanced technique. we used a pre-trained ML model to create additional training NLP data.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Sentense flow

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug.augmenter.word
import nlpaug.augmenter.sentence
import nlpaug.flow
pluto.ai_aug_glove = nlpaug.augmenter.word.WordEmbsAug(
    model_type='glove', model_path='glove.6B.300d.txt',
    action="substitute")
#
pluto.ai_aug_glove.aug_p=0.5
#
pluto.ai_aug_bert = nlpaug.augmenter.word.ContextualWordEmbsAug(
    model_path='bert-base-uncased', 
    action='substitute', top_k=20)

# %%
# %%writefile -a {pluto_chapter_6}

import nlpaug
@add_method(PacktDataAug)
def print_aug_ai_sequential(self, df, 
  aug_name="T5_summary",
  bsize=4):
  aug_func = nlpaug.flow.Sequential([self.ai_aug_bert, self.ai_aug_glove])
  orig = df[aug_name][0]
  self._print_aug_ai(orig, aug_func,bsize=bsize, aug_name=aug_name)
  return

# %%
pluto.df_t5_carroll.T5_summary[0]
# Out:
# 'white rabbit with pink eyes runs close by a daisy-chain maker. the daisies are made from a variety of flowers.'

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_carroll)
# Out:
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_75097 th {
#   font-size: 20px;
# }
# #T_75097 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_75097" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75097_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75097_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_75097_row0_col0" class="data row0 col0" >some miniature taking skirt watching runs close in a quarter - figural maker. the daisies here formed year when variety devoid stalks.</td>
#     </tr>
#     <tr>
#       <th id="T_75097_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_75097_row1_col0" class="data row1 col0" >and unidentified shared multicolored wig runs time by a dolly - chain maker. because daisies are tangled both instead nosegay of plants.</td>
#     </tr>
#     <tr>
#       <th id="T_75097_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_75097_row2_col0" class="data row2 col0" >wearing rabbit with pink cheeks runs went is keep vanessa - colored gate. fact kaw these picked from a notably o seeds.</td>
#     </tr>
#     <tr>
#       <th id="T_75097_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_75097_row3_col0" class="data row3 col0" >any rabbit first grey ears eighth almost in a nut - nut fujitsu. put kangla himself made from small bouquet of decorations.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_dickens)
# Out:
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_3a595 th {
#   font-size: 20px;
# }
# #T_3a595 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_3a595" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a595_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a595_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a595_row0_col0" class="data row0 col0" >david barkey: beings revelations days conceded might us at favors time. he believed even the five - lane stone it never laid only into round amount of years. the words that this embarrassing year last past whiffed out theirs, he wrote.</td>
#     </tr>
#     <tr>
#       <th id="T_3a595_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a595_row1_col0" class="data row1 col0" >david writes: spiritual revelations are transmitted through england at mfn time. me says when that cock - lane ghost once because laid only once quarter some of several. the spirits in this twenty year last years badgered out theirs, just writes.</td>
#     </tr>
#     <tr>
#       <th id="T_3a595_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3a595_row2_col0" class="data row2 col0" >john rothkopf: life resignation they popular with friends at favoured time. he says might their cock - lane line writin been under only. round dozen of years. the end of this incredibly happy last long rapped out longer, he writes.</td>
#     </tr>
#     <tr>
#       <th id="T_3a595_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3a595_row3_col0" class="data row3 col0" >alexander rothkopf: spiritual embarrassing were conceded to england at opting n't. again says even the cock - cove has only been around only another round dozen of years. the key to the one year long been rapped them theirs, he writes.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_melville)
# Out:
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_37fbe th {
#   font-size: 20px;
# }
# #T_37fbe td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_37fbe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37fbe_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37fbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37fbe_row0_col0" class="data row0 col0" >ishmael tells a sailor whom has the way of digging into the spleen and labeling what papers. learned says only is instead substitute many cup and ball to get to sea in soon as he can. almost all men to his degree, among still or other, cherish with nearly the same trait.</td>
#     </tr>
#     <tr>
#       <th id="T_37fbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37fbe_row1_col0" class="data row1 col0" >hadith is an sailor. .. has once way of driving off the spleen and regulator the circulation. he says it seems his substitute for pistol; ball to come to sea as soon as he can. quite all men in their country, come time by least, are be nearly a same care.</td>
#     </tr>
#     <tr>
#       <th id="T_37fbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_37fbe_row2_col0" class="data row2 col0" >this is the sailor who has another way way driving off the spleen and regulating its circulation. one says it often success scored for pistol and ball to march them sea as soon a ye can. almost all men in their degree, some time not they, cherish very nearly the not instance.</td>
#     </tr>
#     <tr>
#       <th id="T_37fbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_37fbe_row3_col0" class="data row3 col0" >ishmael is a sailor also has a way of driving off the spleen and affecting the circulation. he says rum not his substitute to cannabis although wishes to better to work become quick as he can. 50 all men 1997 their degree, some since or other, cherish should 6,000 the same feelings.</td>
#     </tr>
#   </tbody>
# </table>

# %%
pluto.print_aug_ai_sequential(pluto.df_t5_self)
# Out:
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <ipython-input-57-84a3684ea982>:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_aug = df_aug.append(t, ignore_index=True)
# <style type="text/css">
# #T_cfcc9 th {
#   font-size: 20px;
# }
# #T_cfcc9 td {
#   font-size: 18px;
#   text-align: left;
# }
# </style>
# <table id="T_cfcc9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfcc9_level0_col0" class="col_heading level0 col0" >T5_summary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfcc9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cfcc9_row0_col0" class="data row0 col0" >web models came point learning (mg/l) required this mannerisms perfected. we used that emptively - trained text model for could additional abstract nlp 7-6.</td>
#     </tr>
#     <tr>
#       <th id="T_cfcc9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cfcc9_row1_col0" class="data row1 col0" >translated instance once machine teaches (ml) are put advanced application. he utilized a pre - tutors lab form of create and preparation nlp periodicals.</td>
#     </tr>
#     <tr>
#       <th id="T_cfcc9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cfcc9_row2_col0" class="data row2 col0" >process linewidth or tank learning (mat) example an advanced technique. once provide a software - replaced guadalupe model cannot opportunity additional workouts method suggesting.</td>
#     </tr>
#     <tr>
#       <th id="T_cfcc9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cfcc9_row3_col0" class="data row3 col0" >ability augmentation through enables children (ml) is both climbed procedures. we extend the phase - trained imagery called to create additional vocabulary nlp data.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# end of chapter 6
print('end of chatper 6')
# Out:
# end of chatper 6

# %% [markdown]
# # Push up all changes (Optional)

# %%
# import os
# f = 'Data-Augmentation-with-Python'
# os.chdir(f)
# !git add -A
# !git config --global user.email "duc.haba@gmail.com"
# !git config --global user.name "duchaba"
# !git commit -m "end of session"
# # do the git push in the xterm console
# #!git push

# %% [markdown]
# # Summary
#
# Every chaper will begin with same base class "PacktDataAug".
#
# ✋ FAIR WARNING:
#
# - The coding uses long and complete function path name.
#
# - Pluto wrote the code for easy to understand and not for compactness, fast execution, nor cleaverness.
#
# - Use Xterm to debug cloud server

# %%
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
